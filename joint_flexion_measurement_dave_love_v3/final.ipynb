# %% [markdown]
# #### IMPORT AND INSTALL DEPENDENCIES

# %%
import tensorflow as tf
import cv2,labelme
import shutil
from pathlib import Path
import os,uuid,time,json
import mediapipe as mp
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.models import load_model
from filterpy.kalman import KalmanFilter
import matplotlib.pyplot as plt
import numpy as np,pandas as pd

from reportlab.pdfgen import canvas
from reportlab.lib.pagesizes import letter
from PyPDF2 import PdfMerger

import os,cvzone
from ultralytics import YOLO
from sort import *

# %% [markdown]
# #### ANALYTIC FUNCTIONS

# %%
mp_holistic = mp.solutions.holistic
holistic = mp_holistic.Holistic()
mp_drawing = mp.solutions.drawing_utils
mp_drawing_styles = mp.solutions.drawing_styles


def get_angles(results):
        mp_pose = mp.solutions.pose
        wrist = results.pose_landmarks.landmark[mp_pose.PoseLandmark.RIGHT_WRIST]
        index = results.pose_landmarks.landmark[mp_pose.PoseLandmark.RIGHT_INDEX]
        elbow = results.pose_landmarks.landmark[mp_pose.PoseLandmark.RIGHT_ELBOW]

        # Convert landmarks to numpy arrays
        wrist = np.array([wrist.x, wrist.y, wrist.z])
        index = np.array([index.x, index.y, index.z])
        elbow = np.array([elbow.x, elbow.y, elbow.z])

        # Calculate the vectors
        v1 = index - wrist
        v2 = elbow - wrist

        # Calculate the angle using arccos
        wrist_angle = np.degrees(np.arccos(np.dot(v1, v2) / (np.linalg.norm(v1) * np.linalg.norm(v2))))

        wrist_angle = wrist_angle.astype(int)


        # Calculate the right elbow angle
        shoulder = results.pose_landmarks.landmark[mp_pose.PoseLandmark.RIGHT_SHOULDER]
        elbow = results.pose_landmarks.landmark[mp_pose.PoseLandmark.RIGHT_ELBOW]
        wrist = results.pose_landmarks.landmark[mp_pose.PoseLandmark.RIGHT_WRIST]
        shoulder = np.array([shoulder.x, shoulder.y])
        elbow = np.array([elbow.x, elbow.y])
        wrist = np.array([wrist.x, wrist.y])
        v1 = shoulder - elbow
        v2 = wrist - elbow
        elbow_angle = np.arccos(np.dot(v1, v2) / (np.linalg.norm(v1) * np.linalg.norm(v2)))
        elbow_angle = np.degrees(elbow_angle).astype(int)


        # Calculate the right shoulder angle
        hip = results.pose_landmarks.landmark[mp_pose.PoseLandmark.RIGHT_HIP]
        shoulder = results.pose_landmarks.landmark[mp_pose.PoseLandmark.RIGHT_SHOULDER]
        elbow = results.pose_landmarks.landmark[mp_pose.PoseLandmark.RIGHT_ELBOW]
        shoulder = np.array([shoulder.x, shoulder.y,shoulder.z])
        hip = np.array([hip.x, hip.y,hip.z])
        elbow = np.array([elbow.x, elbow.y,elbow.z])

        v1 = elbow[:2] - shoulder[:2]
        v2 = hip[:2] - shoulder[:2]
        shoulder_angle = np.arccos(np.dot(v2, v1) / (np.linalg.norm(v2) * np.linalg.norm(v1)))
        shoulder_angle = np.degrees(shoulder_angle).astype(int)
        
        if elbow[0] < shoulder[0]:
            shoulder_angle = -shoulder_angle
        else:
            if abs(shoulder_angle) >= 60:
                v1 = elbow - shoulder
                v2 = hip - shoulder
                shoulder_angle = np.arccos(np.dot(v2, v1) / (np.linalg.norm(v2) * np.linalg.norm(v1)))
                shoulder_angle = np.degrees(shoulder_angle).astype(int)
            else:
                shoulder_angle = abs(shoulder_angle)

        # Calculate the hip angle
        hip = results.pose_landmarks.landmark[mp_pose.PoseLandmark.RIGHT_HIP]
        hip = np.array([hip.x, hip.y,hip.z])
        knee = results.pose_landmarks.landmark[mp_pose.PoseLandmark.RIGHT_KNEE]
        knee = np.array([knee.x, knee.y, knee.z])
        shoulder = results.pose_landmarks.landmark[mp_pose.PoseLandmark.RIGHT_SHOULDER]
        shoulder = np.array([shoulder.x, shoulder.y,shoulder.z])
        v1 = shoulder - hip
        v2 = knee - hip
        hip_angle = np.arccos(np.dot(v1, v2) / (np.linalg.norm(v1) * np.linalg.norm(v2)))
        hip_angle = np.degrees(hip_angle).astype(int)

        # Calculate the right knee angle
        ankle = results.pose_landmarks.landmark[mp_pose.PoseLandmark.RIGHT_ANKLE]
        ankle = np.array([ankle.x, ankle.y, ankle.z])
        v1 = hip - knee
        v2 = ankle - knee
        knee_angle = np.arccos(np.dot(v1, v2) / (np.linalg.norm(v1) * np.linalg.norm(v2)))
        knee_angle = np.degrees(knee_angle).astype(int)

        # Calculate the right ankle angle
        heel = results.pose_landmarks.landmark[mp_pose.PoseLandmark.RIGHT_HEEL]
        heel = np.array([heel.x, heel.y, heel.z])
        v1 = knee - ankle
        v2 = heel - ankle
        ankle_angle = np.arccos(np.dot(v1, v2) / (np.linalg.norm(v1) * np.linalg.norm(v2)))
        ankle_angle = np.degrees(ankle_angle).astype(int) 

        return [wrist_angle,elbow_angle,shoulder_angle,hip_angle,knee_angle,ankle_angle]



def display_angle_table(frame,results,width,height):
    
    wrist_angle,elbow_angle,shoulder_angle,hip_angle,knee_angle,ankle_angle = get_angles(results)

    cv2.rectangle(frame, (width - 600, height - 250), (width, height), (0, 0, 0), cv2.FILLED)
    cv2.line(frame,(width - 600, height - 250), (width - 600, height ), (255,255,255), 4)
    for i in [250,210,170,130,90,50]:
        cv2.line(frame, (width - 600, height - i), (width, height - i), (255,255,255), 4)
    cv2.putText(frame, f'wrist angle: {wrist_angle}', (width - 600, height - 220), cv2.FONT_HERSHEY_COMPLEX, 1, (0, 0, 255), 2, cv2.LINE_AA)
    cv2.putText(frame, f'elbow angle: {elbow_angle}', (width - 600, height - 180), cv2.FONT_HERSHEY_COMPLEX, 1, (255, 0, 0), 2, cv2.LINE_AA)
    cv2.putText(frame, f'shoulder angle: {shoulder_angle}', (width - 600, height - 140), cv2.FONT_HERSHEY_COMPLEX, 1, (0, 255, 0), 2, cv2.LINE_AA)
    cv2.putText(frame, f'Hip angle: {hip_angle}', (width - 600, height - 100), cv2.FONT_HERSHEY_SIMPLEX, 1, (255, 255, 0), 2, cv2.LINE_AA)
    cv2.putText(frame, f'knee angle: {knee_angle}', (width - 600, height - 60), cv2.FONT_HERSHEY_SIMPLEX, 1, (255, 0, 255), 2, cv2.LINE_AA)
    cv2.putText(frame, f'ankle angle: {ankle_angle}', (width - 600, height - 20), cv2.FONT_HERSHEY_SIMPLEX, 1, (0, 255, 255), 2, cv2.LINE_AA)
    return [wrist_angle,elbow_angle,shoulder_angle,hip_angle,knee_angle,ankle_angle]


def mediapipe_detection(image,model):
    image = cv2.cvtColor(image,cv2.COLOR_BGR2RGB)
    results = model.process(image)
    image = cv2.cvtColor(image,cv2.COLOR_RGB2BGR)
    return results

def draw_landmarks(image,results):
    mp_drawing.draw_landmarks(image, results.pose_landmarks, mp_holistic.POSE_CONNECTIONS,
                                  mp_drawing.DrawingSpec(color=(10, 250, 80), thickness=2, circle_radius=4),
                                  mp_drawing.DrawingSpec(color=(250, 0, 0), thickness=2, circle_radius=2),)
    mp_drawing.draw_landmarks(image, results.right_hand_landmarks, mp_holistic.HAND_CONNECTIONS,
                                  mp_drawing.DrawingSpec(color=(0, 250, 80), thickness=2, circle_radius=4),
                                  mp_drawing.DrawingSpec(color=(250, 0, 250), thickness=2, circle_radius=2),)
    mp_drawing.draw_landmarks(image, results.left_hand_landmarks, mp_holistic.HAND_CONNECTIONS,
                                  mp_drawing.DrawingSpec(color=(10, 250, 80), thickness=2, circle_radius=4),
                                  mp_drawing.DrawingSpec(color=(121, 121, 255), thickness=2, circle_radius=2),)
    

def extract_keypoint(results):
    face = np.array([[res.x,res.y,res.z] for res in results.face_landmarks.landmark]).flatten() if results.face_landmarks else np.zeros(468*3)
    pose = np.array([[res.x,res.y,res.z,res.visibility] for res in results.pose_landmarks.landmark]).flatten() if results.pose_landmarks else np.zeros(33*4)
    rh = np.array([[res.x,res.y,res.z] for res in results.right_hand_landmarks.landmark]).flatten() if results.right_hand_landmarks else np.zeros(21*3)
    lh = np.array([[res.x,res.y,res.z] for res in results.left_hand_landmarks.landmark]).flatten() if results.left_hand_landmarks else np.zeros(21*3)
    return np.concatenate([pose,face,lh,rh])

def extract_images(video_path,output_folder,frames_to_extract):
    '''
    extracts images from video
    
    Arguments: 
        video_path: this is the path to the video we are extracting image from
        output_file: this is the directory our extracted image will be saved to
        frame_interval_seconds: this is the seconds interval to save each image
    '''

    cap = cv2.VideoCapture(video_path)
    frame_count = 0
    frame_on_save = 0

    Path(output_folder).mkdir(exist_ok=True)
    folder_name = Path(video_path).stem

    while cap.isOpened():
        ret,frame = cap.read()
        if not ret:
            break

        frame_count += 1

        # Save the frame if it's within the desired interval
        if  frame_count in frames_to_extract:

            final_npy_dir = Path(output_folder,folder_name,f"{frame_on_save}.npy")
            image_np = np.array(frame)
        
            input_tensor = tf.convert_to_tensor(np.expand_dims(image_np, 0), dtype=tf.float32)
            detections = detect_fn(input_tensor)
            
            num_detections = int(detections.pop('num_detections'))
            detections = {key: value[0, :num_detections].numpy()
                            for key, value in detections.items()}
            detections['num_detections'] = num_detections

            # detection_classes should be ints.
            detections['detection_classes'] = detections['detection_classes'].astype(np.int64)

            label_id_offset = 1
            image_np_with_detections = image_np.copy()

            # for i in range(len(detections['detection_boxes'])):
            box = detections['detection_boxes'][0]
            ymin, xmin, ymax, xmax = box
            ymin, xmin, ymax, xmax = int(ymin * height), int(xmin * width), int(ymax * height), int(xmax * width)

            player_frame = image_np[ymin:ymax, xmin:xmax]
            output_path = Path(output_folder, f"{str(uuid.uuid1())}.jpg")
            print(output_path)
            cv2.imwrite(str(output_path), player_frame)
    cap.release()

def view_fn(path,starting_point):
    cap = cv2.VideoCapture(path)
    frame_count = 0
    frame_to_save = 0
    folder_name = Path(path).stem
    with mp_holistic.Holistic(min_detection_confidence=0.5,min_tracking_confidence=0.5) as holistic:
        while cap.isOpened():
            ret,frame = cap.read()
            if not ret:
                break
            
            frame_count += 1
            image_np = np.array(frame)
            
            input_tensor = tf.convert_to_tensor(np.expand_dims(image_np, 0), dtype=tf.float32)
            detections = detect_fn(input_tensor)
            
            num_detections = int(detections.pop('num_detections'))
            detections = {key: value[0, :num_detections].numpy()
                            for key, value in detections.items()}
            detections['num_detections'] = num_detections

            # detection_classes should be ints.
            detections['detection_classes'] = detections['detection_classes'].astype(np.int64)

            label_id_offset = 1
            image_np_with_detections = image_np.copy()

            # for i in range(len(detections['detection_boxes'])):
            box = detections['detection_boxes'][0]
            ymin, xmin, ymax, xmax = box
            ymin, xmin, ymax, xmax = int(ymin * height), int(xmin * width), int(ymax * height), int(xmax * width)

            player_frame = image_np[ymin:ymax, xmin:xmax]
            
            margin = 50

            text_x = max(min(xmin - margin, player_frame.shape[0] - 150), 0)
            text_y = max(min(ymin - margin, player_frame.shape[1] - 150), 0)

            
            if text_x < player_frame.shape[1] and text_y < player_frame.shape[0]:
                cv2.putText(player_frame, f'{frame_count}', (text_x, text_y), cv2.FONT_HERSHEY_SIMPLEX, 1, (0, 0, 255), 2, cv2.LINE_AA)
            else:
                print("Text coordinates exceed frame dimensions.")
            cv2.imshow('frame',player_frame)
            

            if frame_count in np.arange(starting_point,starting_point + 25):
                image,results = mediapipe_detection(player_frame,holistic)
                extracted_results = extract_keypoint(results)
                final_npy_dir = Path('shot_detection_images','0',folder_name,f"{frame_to_save}.npy")
                Path('shot_detection_images','0',folder_name).mkdir(exist_ok=True)
                np.save(final_npy_dir,extracted_results)
                draw_landmarks(image,results)
                mp_drawing.draw_landmarks(player_frame, results.pose_landmarks, mp_holistic.POSE_CONNECTIONS,
                                        mp_drawing.DrawingSpec(color=(10, 250, 80), thickness=2, circle_radius=4),
                                        mp_drawing.DrawingSpec(color=(250, 0, 0), thickness=2, circle_radius=2),)
                frame_to_save += 1
            elif frame_count > starting_point + 25:
                break

        cap.release()
        cv2.destroyAllWindows()

def create_dataframe(keypoints,name_to_save):
    df = pd.DataFrame(keypoints,columns=['wrist_angle','elbow_angle','shoulder_angle','hip_angle','knee_angle','ankle_angle'])
    df.index = range(1, len(df) + 1)
    df.to_excel(f"{name_to_save}.xlsx")

def kalman_filter(y):
    y = np.array(y)
        # Initialize Kalman filter parameters
    kf = KalmanFilter(dim_x=1, dim_z=1)
    kf.F = np.array([[1]])
    kf.H = np.array([[1]])
    
    kf.Q = np.array([[1e-3]])
    kf.R = np.array([[1e-1]])
    kf.x = np.array([y[0]])

    kf.P *= 1e-2
    smoothed_values = []
    for measurement in y:
        kf.predict()
        kf.update(measurement)
        smoothed_values.append(kf.x[0])
    return smoothed_values


def plot_angle_graph_and_save(frames,angles,save_as,release_frame):
    x = np.array(frames)
    y = np.array(angles)

    def normalize_to_range(arrays, target_range=(-10, 30)):
    
        min_val = np.min(arrays)
        max_val = np.max(arrays)

        # Calculate the scaling factor
        scale_factor = (target_range[1] - target_range[0]) / (max_val - min_val)

        # Normalize each array
        normalized_arrays = [(array - min_val) * scale_factor + target_range[0] for array in arrays]

        return normalized_arrays

    x = x[:len(y)]
    labels = ["wrist_angle", "elbow_angle", "shoulder_angle", "hip_angle", "knee_angle", "ankle_angle"]
    labels_to_normalize = ["elbow_angle","hip_angle", "knee_angle", "ankle_angle"]
    normalization_threshold = { "hip_angle":(-30,0), "knee_angle":(0,-45), "ankle_angle":(-20,40)}
    df = pd.DataFrame(y,index=x,columns=labels)

    


    labels_to_plot = ["elbow_angle", "shoulder_angle", "wrist_angle","hip_angle", "knee_angle", "ankle_angle"]

    for col in labels_to_plot:
        y = df.loc[:,col]
        

        if col in labels_to_plot[3:]:
            y = normalize_to_range(y)

        if col != 'wrist_angle':
            y_smooth = kalman_filter(y)
        else:
            y = [-value for value in y]
            y_smooth = kalman_filter(y)
            
        if col in labels_to_plot[3:]:
            plt.plot(x, y_smooth, label=col,linewidth=0.4)
        else:
            plt.plot(x, y_smooth, label=col)

    plt.axvline(x=release_frame, color='red', linestyle='--', label='Released')
    plt.title("Joint Flexion graph")
    plt.xlabel("frames")
    plt.ylabel("angles")
    plt.legend(loc="upper left", prop={'size':5})

    # Save the plot
    plt.savefig(save_as)
    plt.close()


def resize_image(img):
    target_width = 100
    height, width, _ = img.shape
    aspect_ratio = height / width
    target_height = int(target_width * aspect_ratio)
    resized_img = cv2.resize(img, (target_width, target_height))

    return resized_img


def create_pdf(pdf_filename, image_paths, folder_name,angles):
    c = canvas.Canvas(pdf_filename, pagesize=letter)

    # Add a header with the folder name
    c.setFont("Helvetica", 12)
    c.drawString(100, 750, f'Shot: #{folder_name}')


    # Draw the first image on the left side
    c.drawImage(image_paths[0], 100, 500, width=80, height=100)

    # Draw the second image on the right side
    c.drawImage(image_paths[1], 200, 500, width=300, height=200)
    c.showPage()
    c.save()

def create_combined_pdf(main_folder, pdf_filename,angles):
    merger = PdfMerger()
    print(angles)
    # Iterate through subfolders
    for subfolder in os.listdir(main_folder):
        subfolder_path = os.path.join(main_folder, subfolder)

        # Check if the item in the main folder is a subfolder
        if os.path.isdir(subfolder_path):

            # List image files in the subfolder
            image_files = [file for file in os.listdir(subfolder_path) if file.lower().endswith(('.png', '.jpg', '.jpeg'))]

            # Check if there are exactly 2 image files
            i = 0
            if len(image_files) == 2:
                image_paths = [os.path.join(subfolder_path, file) for file in image_files]
                
                # sheet_filename = f'{subfolder}.pdf'
                sheet_filename = os.path.join(subfolder_path,f'{subfolder}.pdf')

                # Create a PDF for each subfolder
                create_pdf(sheet_filename, image_paths, subfolder,angles[i])
                print(f'PDF created for {subfolder}')

                # Append the sheet to the main PDF
                merger.append(sheet_filename)
                i += 1
            else:
                print(f'Subfolder {subfolder} does not contain 2 images.')

    # Save the final PDF
    merger.write(pdf_filename)
    merger.close()

    # Remove individual subfolder PDFs
    for subfolder in os.listdir(main_folder):
        subfolder_path = os.path.join(main_folder, subfolder)
        if os.path.isdir(subfolder_path):
            pdf_path = os.path.join(main_folder,subfolder_path, f'{subfolder}.pdf')
            print(pdf_path)
            if os.path.exists(pdf_path):
                os.remove(pdf_path)

    print('PDF creation complete.')


def get_shot_pose_image(frame_num, player_angles, player_frame):
    assert len(frame_num) == len(player_angles) == len(player_frame)
    cols = ['wrist_angle', 'elbow_angle', 'shoulder_angle', 'hip_angle', 'knee_angle', 'ankle_angle']
    df = pd.DataFrame(player_angles, index=np.arange(len(frame_num)).tolist(), columns=cols)

    # Get the indices of the first 5 maximum values of shoulder_angle
    shoulder_max_indices = df['shoulder_angle'].nlargest(10).index.tolist()

    # Choose the first 3 maximum values of elbow_angle within the shoulder_max_indices
    # wrist_max_indices = df.loc[shoulder_max_indices]['wrist_angle'].nsmallest(3).index.tolist()
    elbow_max_indices = df.loc[shoulder_max_indices]['elbow_angle'].nsmallest(7).index.tolist()

    # Choose the index with the lowest value of wrist_angle within the elbow_max_indices
    final_index = df.loc[elbow_max_indices]['wrist_angle'].idxmin()
    # final_index = df.loc[wrist_max_indices]['elbow_angle'].idxmin()

    return final_index

def get_contact_prediction_and_index(images):
    results = []
    model = load_model('contact_detection.h5')

    def preprocess(img):
        handball_frame = cv2.cvtColor(img,cv2.COLOR_BGR2RGB)
        handball_contact = tf.image.resize(handball_frame,(120,120))
        normalized_contact = handball_contact / 255.0
        handball_contact = np.expand_dims(normalized_contact,axis=0)
        prediction = model.predict(handball_contact)
        return prediction[0]
        
    for image in images:
        results.append(preprocess(image))
    
    index = np.argmax(results)
    return index
        

coco_classes = [
    "Person", "Bicycle", "Car", "Motorcycle", "Airplane", "Bus", "Train", "Truck", "Boat", "Traffic light",
    "Fire hydrant", "Stop sign", "Parking meter", "Bench", "Bird", "Cat", "Dog", "Horse", "Sheep", "Cow",
    "Elephant", "Bear", "Zebra", "Giraffe", "Backpack", "Umbrella", "Handbag", "Tie", "Suitcase", "Frisbee",
    "Skis", "Snowboard", "Sports ball", "Kite", "Baseball bat", "Baseball glove", "Skateboard", "Surfboard",
    "Tennis racket", "Bottle", "Wine glass", "Cup", "Fork", "Knife", "Spoon", "Bowl", "Banana", "Apple",
    "Sandwich", "Orange", "Broccoli", "Carrot", "Hot dog", "Pizza", "Donut", "Cake", "Chair", "Couch",
    "Potted plant", "Bed", "Dining table", "Toilet", "TV", "Laptop", "Mouse", "Remote", "Keyboard",
    "Cell phone", "Microwave", "Oven", "Toaster", "Sink", "Refrigerator", "Book", "Clock", "Vase",
    "Scissors", "Teddy bear", "Hair drier", "Toothbrush"
]

# %% [markdown]
# #### FUNCTIONS FOR INFERENCE

# %%
def init_video_capture_and_writer(path):
    ''' initialize video capture and writer'''
    cap = cv2.VideoCapture(path)
    fps = cap.get(cv2.CAP_PROP_FPS)
    width = int(cap.get(cv2.CAP_PROP_FRAME_WIDTH))
    height = int(cap.get(cv2.CAP_PROP_FRAME_HEIGHT))
    return cap, fps, width, height

def process_frame(frame,model_yolo,labels):
    detections = np.empty((0,5))
    results = model_yolo(frame)
    for result in results:
        boxes = result.boxes
        for box in boxes:
            x1,y1,x2,y2 = np.array(box.xyxy[0]).astype(int)
            conf = box.conf[0]
            cls = labels[int(box.cls[0])]
            if cls == 'Person' and conf>0.3:
                currentArray = [x1,y1,x2,y2,conf]
                detections = np.vstack((detections,currentArray))
    return detections

def analyze_pose_and_predict(sequence,y_predict, actions):
    global shot_buffer,waiting_buffer,shot_frame_count,WAITING_BUFFER_SIZE
    y_predict = np.argmax(y_predict)
    shot_label = actions[y_predict]
    shot_buffer.append(shot_label)
    waiting_buffer.append(shot_label)

    if len(shot_buffer) > BUFFER_SIZE:
        shot_buffer.pop(0)

    if len(waiting_buffer) > WAITING_BUFFER_SIZE:
        waiting_buffer.pop(0)

    if shot_buffer.count('shot') >= THRESHOLD:
        shot_frame_count += 1
    
    


def handle_shot_detection(shot_frame_count_max,WAITING_BUFFER_SIZE,shot_buffer,BUFFER_SIZE,shot_frame_count, waiting_buffer, player_image_frame, at_shot_frame_num, at_shot_frame_angles, shot_num, path):
    global angles_to_pdf
    
    if shot_frame_count >= shot_frame_count_max:
        if waiting_buffer[-WAITING_BUFFER_SIZE:].count('noshot') == round(0.7*WAITING_BUFFER_SIZE):
            shot_num += 1
            max_contact_index = get_contact_prediction_and_index(player_image_frame)
            
            frames_to_plot = at_shot_frame_num[max_contact_index-70:max_contact_index+130]
            angles_to_plot = at_shot_frame_angles[max_contact_index-70:max_contact_index+130]
            angles_for_pdf.append(at_shot_frame_angles[max_contact_index])

            Path('report').mkdir(exist_ok=True)
            at_shot_dir = Path('report') / Path(path).stem / f"{shot_num}"
            at_shot_dir.mkdir(parents=True,exist_ok=True)
            img_path = at_shot_dir / f"{shot_num}.jpg"
            graph_path = at_shot_dir / f"graph_{shot_num}.png"
            shot_frame_count = 0

            plot_angle_graph_and_save(frames_to_plot,angles_to_plot,str(graph_path),release_frame=at_shot_frame_num[max_contact_index])
            cv2.imwrite(str(img_path),player_image_frame[max_contact_index])
            at_shot_frame_num = []
            at_shot_frame_angles = []
            player_image_frame = []
            shot_frame_count = 0
        else:
            if shot_buffer[-BUFFER_SIZE:].count('noshot') == BUFFER_SIZE:
                shot_frame_count = 0
    
    return shot_num, at_shot_frame_num, at_shot_frame_angles, player_image_frame, shot_frame_count

# %%
yolo_model = YOLO('yolov8l.pt')

# %%
def do_analysis(path):    
    player_image_frame = []
    player_image_keypoint = []
    at_shot_frame_num = []
    at_shot_frame_angles = []
    actions = {0:'noshot',1:'shot'}

    tracker = Sort(max_age=20,min_hits=3,iou_threshold=0.3)
    first_frame = True
    frame_count = 0
    cap, fps, width, height= init_video_capture_and_writer(path)

    BUFFER_SIZE = 20 if fps < 70 else 30  # Adjust as needed
    WAITING_BUFFER_SIZE = BUFFER_SIZE + 20

    THRESHOLD = 10 if fps < 70 else 25 # Adjust as needed
    shot_frame_count_max = 12 if fps < 70 else 8
    shot_buffer = []
    waiting_buffer = []
    shot_frame_count= 0
    sequences = []
    mp_pose = mp.solutions.pose
    shot_num = 0
    angles_for_pdf = []
    total_count = []
    labels = ['Person']

    output_video_path = 'output_vid/' + str(Path(path).stem) + '.avi'
    Path('output_vid/').mkdir(exist_ok=True)
    fourcc = cv2.VideoWriter_fourcc(*'XVID') 
    output_video_writer = cv2.VideoWriter(output_video_path, fourcc, fps, (width, height))

    shot_model = load_model('shot_detection_lstm.h5')
    with mp_pose.Pose() as pose:
        while cap.isOpened():
            ret,frame = cap.read()
            if not ret:
                break
            
            # output_video_writer.write(frame)
            if cv2.waitKey(1) & 0xFF == ord('q'):
               print('done')
               break

            if not ret:
               break

            frame_count += 1
            at_shot_frame_num.append(frame_count)
            
            cv2.putText(frame, f'Frame: {frame_count}', (10, 30), cv2.FONT_HERSHEY_SIMPLEX, 1, (255, 255, 255), 2, cv2.LINE_AA)
            cv2.putText(frame, f'FPS: {fps:.2f}', (10, 70), cv2.FONT_HERSHEY_SIMPLEX, 1, (255, 255, 255), 2, cv2.LINE_AA)
            cv2.putText(frame, f'Shot number: {shot_num}', (10, 100), cv2.FONT_HERSHEY_SIMPLEX, 1, (255, 255, 255), 2, cv2.LINE_AA)
            # cv2.putText(image_np, f'Shot frame count: {shot_frame_count}', (10, 130), cv2.FONT_HERSHEY_SIMPLEX, 1, (255, 255, 255), 2, cv2.LINE_AA)


            detections = process_frame(frame,yolo_model,coco_classes)
            
            track_results = tracker.update(detections)
            for result in track_results:
                x1,y1,x2,y2,id = np.array(result).astype(int)
                if first_frame:
                    w,h = x2-x1,y2-y1

                    cv2.rectangle(frame, (max(0,x1-70), max(0,y1-70)), (max(0,x2+70), max(0,y2+70)), (0,255,0), 2)
                    cvzone.putTextRect(frame,str(id),(max(0,x1-70),max(20,y1-70)),scale=1,thickness=2,offset=5)
                elif id == object_id_to_track:
                    w,h = x2-x1,y2-y1

                    cv2.rectangle(frame, (max(0,x1-70), max(0,y1-70)), (max(0,x2+70), max(0,y2+70)), (0,255,0), 2)
                    cvzone.putTextRect(frame,str(id),(max(0,x1-70),max(20,y1-70)),scale=1,thickness=2,offset=5)     

                    if w>0 and h>0:
                        player_frame = frame[max(0,y1-70):max(0,y2+70), max(0,x1-70):max(0,x2+70)]

                    if player_frame.size != 0:
                            player_frame_to_save = player_frame.copy()
                            player_image_frame.append(player_frame_to_save)
                            results = mediapipe_detection(player_frame,holistic)
                            keypoints = extract_keypoint(results)
                            player_image_keypoint.append(keypoints)

                    draw_landmarks(player_frame,results)
                    if results.pose_landmarks:
                        wrist_angle,elbow_angle,shoulder_angle,hip_angle,knee_angle,ankle_angle = display_angle_table(frame,results,width,height)
                        item_list = [wrist_angle,elbow_angle,shoulder_angle,hip_angle,knee_angle,ankle_angle]
                        at_shot_frame_angles.append(item_list)
                    else:
                        item_list = [0,0,0,0,0,0]
                        at_shot_frame_angles.append(item_list)
                    
                    sequences.append(keypoints)
                    sequence = sequences[-5:]
                    if len(sequence) == 5:
                        y_predict = shot_model.predict(np.expand_dims(sequence,axis=0))
                        y_predict = np.argmax(y_predict)
                        shot_label = actions[y_predict]
                        shot_buffer.append(shot_label)
                        waiting_buffer.append(shot_label)

                        if len(shot_buffer) > BUFFER_SIZE:
                           shot_buffer.pop(0)

                        if len(waiting_buffer) > WAITING_BUFFER_SIZE:
                           waiting_buffer.pop(0)

                        if shot_buffer.count('shot') >= THRESHOLD:
                           shot_frame_count += 1

                        if shot_frame_count >= shot_frame_count_max:
                           if waiting_buffer[-WAITING_BUFFER_SIZE:].count('noshot') == round(0.7*WAITING_BUFFER_SIZE):
                              shot_num += 1
                              max_contact_index = get_contact_prediction_and_index(player_image_frame)
                              
                              frames_to_plot = at_shot_frame_num[max_contact_index-70:max_contact_index+130]
                              angles_to_plot = at_shot_frame_angles[max_contact_index-70:max_contact_index+130]
                              angles_for_pdf.append(at_shot_frame_angles[max_contact_index])

                              Path('report').mkdir(exist_ok=True)
                              at_shot_dir = Path('report') / Path(path).stem / f"{shot_num}"
                              at_shot_dir.mkdir(parents=True,exist_ok=True)
                              img_path = at_shot_dir / f"{shot_num}.jpg"
                              graph_path = at_shot_dir / f"graph_{shot_num}.png"
                              shot_frame_count = 0

                              plot_angle_graph_and_save(frames_to_plot,angles_to_plot,str(graph_path),release_frame=at_shot_frame_num[max_contact_index])
                              cv2.imwrite(str(img_path),player_image_frame[max_contact_index])
                              at_shot_frame_num = []
                              at_shot_frame_angles = []
                              player_image_frame = []
                              shot_frame_count = 0
                        else:
                           if shot_buffer[-BUFFER_SIZE:].count('noshot') == BUFFER_SIZE:
                              shot_frame_count = 0
                    
            if first_frame:
                cv2.imshow('frame', cv2.resize(frame, (1200, 600)))
                output_video_writer.write(frame)
                cv2.waitKey(0)
                object_id_to_track = int(input('Enter the object id you want to track'))
                first_frame = False
            else:
                cv2.imshow('frame', cv2.resize(frame, (1200, 600)))
                output_video_writer.write(frame)
                

        
            if cv2.waitKey(1) & 0xFF == ord('q'):
                break

    cap.release()
    cv2.destroyAllWindows()
    output_video_writer.release()
            
    pdf_init_path = os.path.join('report',f"{str(Path(path).stem)}")
    Path(pdf_init_path).mkdir(parents=True,exist_ok=True)
    create_combined_pdf(pdf_init_path, os.path.join(pdf_init_path,f"{str(Path(path).stem)}_shot_report.pdf"),angles_for_pdf)


do_analysis(r'C:\Users\bkj\Documents\GitHub\projects\Upwork\videos\CharlieBrownDelaware5Shots.mov')
# Out:
# 0: 384x640 3 persons, 1 sports ball, 3129.0ms
# Speed: 56.5ms preprocess, 3129.0ms inference, 28.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 1 sports ball, 1333.3ms
# Speed: 23.4ms preprocess, 1333.3ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 1 sports ball, 1 baseball glove, 1245.1ms
# Speed: 5.1ms preprocess, 1245.1ms inference, 6.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 2 sports balls, 1 clock, 1437.0ms
# Speed: 4.0ms preprocess, 1437.0ms inference, 5.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 3 sports balls, 1314.2ms
# Speed: 5.0ms preprocess, 1314.2ms inference, 5.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 2 sports balls, 1606.6ms
# Speed: 13.0ms preprocess, 1606.6ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
# 1/1 [==============================] - 1s 1s/step
#
# 0: 384x640 4 persons, 2 sports balls, 2213.7ms
# Speed: 6.0ms preprocess, 2213.7ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# 1/1 [==============================] - 0s 65ms/step
#
# 0: 384x640 4 persons, 2 sports balls, 3284.5ms
# Speed: 4.0ms preprocess, 3284.5ms inference, 4.6ms postprocess per image at shape (1, 3, 384, 640)
# 1/1 [==============================] - 0s 53ms/step
#
# 0: 384x640 3 persons, 2 sports balls, 1 clock, 1864.1ms
# Speed: 5.0ms preprocess, 1864.1ms inference, 10.0ms postprocess per image at shape (1, 3, 384, 640)
# 1/1 [==============================] - 0s 58ms/step
#
# 0: 384x640 3 persons, 2 sports balls, 1 clock, 1746.1ms
# Speed: 5.0ms preprocess, 1746.1ms inference, 7.0ms postprocess per image at shape (1, 3, 384, 640)
# 1/1 [==============================] - 0s 38ms/step
#
# 0: 384x640 4 persons, 2 sports balls, 1 clock, 2156.9ms
# Speed: 5.0ms preprocess, 2156.9ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
# 1/1 [==============================] - 0s 52ms/step
#
# 0: 384x640 4 persons, 2 sports balls, 1 clock, 1886.5ms
# Speed: 6.0ms preprocess, 1886.5ms inference, 6.0ms postprocess per image at shape (1, 3, 384, 640)
# 1/1 [==============================] - 0s 36ms/step
#
# 0: 384x640 4 persons, 2 sports balls, 1 clock, 1414.7ms
# Speed: 4.6ms preprocess, 1414.7ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
# 1/1 [==============================] - 0s 40ms/step
#
# 0: 384x640 3 persons, 2 sports balls, 1504.2ms
# Speed: 4.0ms preprocess, 1504.2ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
# 1/1 [==============================] - 0s 40ms/step
#
# 0: 384x640 4 persons, 2 sports balls, 1 clock, 1648.3ms
# Speed: 4.0ms preprocess, 1648.3ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# 1/1 [==============================] - 0s 35ms/step
#
# 0: 384x640 3 persons, 2 sports balls, 1466.3ms
# Speed: 4.0ms preprocess, 1466.3ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# 1/1 [==============================] - 0s 39ms/step
#
# 0: 384x640 4 persons, 2 sports balls, 1 clock, 1305.9ms
# Speed: 3.0ms preprocess, 1305.9ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# 1/1 [==============================] - 0s 42ms/step
#
# 0: 384x640 3 persons, 2 sports balls, 1390.0ms
# Speed: 3.0ms preprocess, 1390.0ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
# 1/1 [==============================] - 0s 48ms/step
#
# 0: 384x640 3 persons, 2 sports balls, 1 clock, 1388.1ms
# Speed: 6.0ms preprocess, 1388.1ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# 1/1 [==============================] - 0s 41ms/step
#
# 0: 384x640 3 persons, 2 sports balls, 1 clock, 1537.2ms
# Speed: 4.5ms preprocess, 1537.2ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
# 1/1 [==============================] - 0s 35ms/step
#
# 0: 384x640 3 persons, 2 sports balls, 1 clock, 1385.4ms
# Speed: 5.0ms preprocess, 1385.4ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# 1/1 [==============================] - 0s 37ms/step
#
# 0: 384x640 3 persons, 2 sports balls, 1 clock, 1236.9ms
# Speed: 4.0ms preprocess, 1236.9ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# 1/1 [==============================] - 0s 45ms/step
#
# 0: 384x640 3 persons, 2 sports balls, 1304.4ms
# Speed: 4.0ms preprocess, 1304.4ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# 1/1 [==============================] - 0s 36ms/step
#
# 0: 384x640 3 persons, 2 sports balls, 1259.7ms
# Speed: 5.0ms preprocess, 1259.7ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# 1/1 [==============================] - 0s 40ms/step
#
# 0: 384x640 3 persons, 2 sports balls, 1 clock, 1333.1ms
# Speed: 5.0ms preprocess, 1333.1ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# 1/1 [==============================] - 0s 38ms/step
#
# 0: 384x640 3 persons, 2 sports balls, 1 clock, 1556.7ms
# Speed: 3.0ms preprocess, 1556.7ms inference, 6.0ms postprocess per image at shape (1, 3, 384, 640)
# 1/1 [==============================] - 0s 60ms/step
#
# 0: 384x640 3 persons, 2 sports balls, 1 clock, 1524.0ms
# Speed: 5.0ms preprocess, 1524.0ms inference, 5.0ms postprocess per image at shape (1, 3, 384, 640)
# 1/1 [==============================] - 0s 40ms/step
#
# 0: 384x640 3 persons, 2 sports balls, 1 clock, 1401.9ms
# Speed: 3.0ms preprocess, 1401.9ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# 1/1 [==============================] - 0s 41ms/step
#
# 0: 384x640 3 persons, 2 sports balls, 1 clock, 1242.1ms
# Speed: 4.0ms preprocess, 1242.1ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
# 1/1 [==============================] - 0s 39ms/step
#
# 0: 384x640 3 persons, 2 sports balls, 1 clock, 2025.5ms
# Speed: 5.0ms preprocess, 2025.5ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# 1/1 [==============================] - 0s 48ms/step
#
# 0: 384x640 3 persons, 2 sports balls, 1 clock, 1297.6ms
# Speed: 2.9ms preprocess, 1297.6ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# 1/1 [==============================] - 0s 36ms/step
#
# 0: 384x640 3 persons, 2 sports balls, 1 clock, 1340.5ms
# Speed: 4.0ms preprocess, 1340.5ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
# 1/1 [==============================] - 0s 41ms/step
#
# 0: 384x640 3 persons, 2 sports balls, 1 clock, 1437.9ms
# Speed: 16.0ms preprocess, 1437.9ms inference, 5.0ms postprocess per image at shape (1, 3, 384, 640)
# 1/1 [==============================] - 0s 33ms/step
#
# 0: 384x640 3 persons, 2 sports balls, 1 clock, 1349.2ms
# Speed: 3.0ms preprocess, 1349.2ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
# 1/1 [==============================] - 0s 41ms/step
#
# 0: 384x640 3 persons, 2 sports balls, 1 clock, 1354.1ms
# Speed: 4.0ms preprocess, 1354.1ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
# 1/1 [==============================] - 0s 35ms/step
#
# 0: 384x640 3 persons, 1 sports ball, 1 clock, 2140.3ms
# Speed: 9.0ms preprocess, 2140.3ms inference, 9.1ms postprocess per image at shape (1, 3, 384, 640)
# 1/1 [==============================] - 0s 81ms/step
#
# 0: 384x640 3 persons, 1 sports ball, 1 clock, 1722.9ms
# Speed: 4.0ms preprocess, 1722.9ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# 1/1 [==============================] - 0s 38ms/step
#
# 0: 384x640 3 persons, 2 sports balls, 1 clock, 1916.6ms
# Speed: 3.0ms preprocess, 1916.6ms inference, 5.0ms postprocess per image at shape (1, 3, 384, 640)
# 1/1 [==============================] - 0s 34ms/step
#
# 0: 384x640 3 persons, 2 sports balls, 1249.2ms
# Speed: 3.0ms preprocess, 1249.2ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# 1/1 [==============================] - 0s 37ms/step
#
# 0: 384x640 4 persons, 2 sports balls, 1289.7ms
# Speed: 3.0ms preprocess, 1289.7ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
# 1/1 [==============================] - 0s 36ms/step
#
# 0: 384x640 3 persons, 2 sports balls, 1336.4ms
# Speed: 3.0ms preprocess, 1336.4ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
# 1/1 [==============================] - 0s 40ms/step
#
# 0: 384x640 3 persons, 2 sports balls, 1 clock, 1365.4ms
# Speed: 6.0ms preprocess, 1365.4ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# 1/1 [==============================] - 0s 35ms/step
#
# 0: 384x640 3 persons, 2 sports balls, 1 clock, 1305.8ms
# Speed: 3.0ms preprocess, 1305.8ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
# 1/1 [==============================] - 0s 34ms/step
#
# 0: 384x640 3 persons, 2 sports balls, 1 clock, 1325.1ms
# Speed: 5.0ms preprocess, 1325.1ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# 1/1 [==============================] - 0s 38ms/step
#
# 0: 384x640 3 persons, 2 sports balls, 1 clock, 1356.6ms
# Speed: 4.0ms preprocess, 1356.6ms inference, 5.0ms postprocess per image at shape (1, 3, 384, 640)
# 1/1 [==============================] - 0s 33ms/step
#
# 0: 384x640 3 persons, 1 sports ball, 1 clock, 1443.2ms
# Speed: 3.0ms preprocess, 1443.2ms inference, 2.5ms postprocess per image at shape (1, 3, 384, 640)
# 1/1 [==============================] - 0s 43ms/step
#
# 0: 384x640 3 persons, 1 sports ball, 1 clock, 1711.1ms
# Speed: 4.0ms preprocess, 1711.1ms inference, 5.0ms postprocess per image at shape (1, 3, 384, 640)
# 1/1 [==============================] - 0s 34ms/step
#
# 0: 384x640 3 persons, 1 sports ball, 1 clock, 1501.6ms
# Speed: 5.0ms preprocess, 1501.6ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
# 1/1 [==============================] - 0s 61ms/step
#
# 0: 384x640 3 persons, 1 clock, 1933.6ms
# Speed: 6.0ms preprocess, 1933.6ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
# 1/1 [==============================] - 0s 38ms/step
#
# 0: 384x640 3 persons, 1 clock, 1453.6ms
# Speed: 3.0ms preprocess, 1453.6ms inference, 6.0ms postprocess per image at shape (1, 3, 384, 640)
# 1/1 [==============================] - 0s 36ms/step
#
# 0: 384x640 3 persons, 1 clock, 1513.4ms
# Speed: 3.0ms preprocess, 1513.4ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
# 1/1 [==============================] - 0s 125ms/step
#
# 0: 384x640 3 persons, 1 clock, 3842.9ms
# Speed: 5.5ms preprocess, 3842.9ms inference, 41.0ms postprocess per image at shape (1, 3, 384, 640)
# 1/1 [==============================] - 0s 232ms/step
#
# 0: 384x640 3 persons, 1 clock, 3262.8ms
# Speed: 16.0ms preprocess, 3262.8ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
# 1/1 [==============================] - 0s 54ms/step
#
# 0: 384x640 3 persons, 1 sports ball, 1 clock, 2122.0ms
# Speed: 5.0ms preprocess, 2122.0ms inference, 6.6ms postprocess per image at shape (1, 3, 384, 640)
# 1/1 [==============================] - 0s 78ms/step
#
# 0: 384x640 3 persons, 1 sports ball, 1 clock, 1855.5ms
# Speed: 6.0ms preprocess, 1855.5ms inference, 8.6ms postprocess per image at shape (1, 3, 384, 640)
# 1/1 [==============================] - 0s 56ms/step
#
# 0: 384x640 3 persons, 1 sports ball, 1 clock, 1686.9ms
# Speed: 5.0ms preprocess, 1686.9ms inference, 5.0ms postprocess per image at shape (1, 3, 384, 640)
# 1/1 [==============================] - 0s 58ms/step
#
# 0: 384x640 3 persons, 1 sports ball, 1 clock, 1522.6ms
# Speed: 5.0ms preprocess, 1522.6ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# 1/1 [==============================] - 0s 57ms/step
#
# 0: 384x640 3 persons, 1 sports ball, 1 clock, 1446.5ms
# Speed: 6.0ms preprocess, 1446.5ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# 1/1 [==============================] - 0s 47ms/step
#
# 0: 384x640 3 persons, 1 sports ball, 1 clock, 1500.4ms
# Speed: 3.0ms preprocess, 1500.4ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# 1/1 [==============================] - 0s 46ms/step
#
# 0: 384x640 3 persons, 1 tennis racket, 1 clock, 1252.4ms
# Speed: 4.0ms preprocess, 1252.4ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# 1/1 [==============================] - 0s 36ms/step
#
# 0: 384x640 3 persons, 1 sports ball, 1 tennis racket, 1 clock, 1568.8ms
# Speed: 4.0ms preprocess, 1568.8ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
# 1/1 [==============================] - 0s 42ms/step
#
# 0: 384x640 4 persons, 1 sports ball, 1 tennis racket, 1 clock, 1300.3ms
# Speed: 16.0ms preprocess, 1300.3ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
# 1/1 [==============================] - 0s 57ms/step
#
# 0: 384x640 3 persons, 1254.0ms
# Speed: 4.0ms preprocess, 1254.0ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
# 1/1 [==============================] - 0s 34ms/step
#
# 0: 384x640 3 persons, 1 sports ball, 1 clock, 1254.5ms
# Speed: 3.0ms preprocess, 1254.5ms inference, 3.5ms postprocess per image at shape (1, 3, 384, 640)
# 1/1 [==============================] - 0s 33ms/step
#
# 0: 384x640 4 persons, 1 sports ball, 1 clock, 1278.8ms
# Speed: 3.0ms preprocess, 1278.8ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# 1/1 [==============================] - 0s 36ms/step
#
# 0: 384x640 4 persons, 1 sports ball, 1 clock, 1311.8ms
# Speed: 4.0ms preprocess, 1311.8ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
# 1/1 [==============================] - 0s 49ms/step
#
# 0: 384x640 4 persons, 1 sports ball, 1 clock, 1393.8ms
# Speed: 5.0ms preprocess, 1393.8ms inference, 20.5ms postprocess per image at shape (1, 3, 384, 640)
# 1/1 [==============================] - 0s 42ms/step
#
# 0: 384x640 4 persons, 1 sports ball, 1 clock, 1392.6ms
# Speed: 40.0ms preprocess, 1392.6ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
# 1/1 [==============================] - 0s 38ms/step
#
# 0: 384x640 4 persons, 1363.0ms
# Speed: 5.0ms preprocess, 1363.0ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
# 1/1 [==============================] - 0s 34ms/step
#
# 0: 384x640 4 persons, 1 sports ball, 1462.0ms
# Speed: 4.0ms preprocess, 1462.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# 1/1 [==============================] - 0s 37ms/step
#
# 0: 384x640 4 persons, 1 sports ball, 1317.4ms
# Speed: 6.3ms preprocess, 1317.4ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# 1/1 [==============================] - 0s 40ms/step
#
# 0: 384x640 5 persons, 1840.7ms
# Speed: 5.0ms preprocess, 1840.7ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
# 1/1 [==============================] - 0s 37ms/step
#
# 0: 384x640 4 persons, 1 sports ball, 1367.3ms
# Speed: 5.0ms preprocess, 1367.3ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# 1/1 [==============================] - 0s 37ms/step
#
# 0: 384x640 4 persons, 1 sports ball, 1536.0ms
# Speed: 5.0ms preprocess, 1536.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# 1/1 [==============================] - 0s 36ms/step
#
# 0: 384x640 4 persons, 1 sports ball, 1342.7ms
# Speed: 4.0ms preprocess, 1342.7ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# 1/1 [==============================] - 0s 36ms/step
#
# 0: 384x640 4 persons, 1 sports ball, 1 clock, 1484.2ms
# Speed: 4.8ms preprocess, 1484.2ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
# 1/1 [==============================] - 0s 36ms/step
#
# 0: 384x640 4 persons, 1 sports ball, 1 clock, 1354.9ms
# Speed: 3.0ms preprocess, 1354.9ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
# 1/1 [==============================] - 0s 39ms/step
#
# 0: 384x640 4 persons, 1 sports ball, 1 clock, 1511.7ms
# Speed: 4.0ms preprocess, 1511.7ms inference, 15.0ms postprocess per image at shape (1, 3, 384, 640)
# 1/1 [==============================] - 0s 39ms/step
#
# 0: 384x640 4 persons, 1 sports ball, 1 clock, 1352.8ms
# Speed: 5.0ms preprocess, 1352.8ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# 1/1 [==============================] - 0s 36ms/step
#
# 0: 384x640 4 persons, 1 sports ball, 1 clock, 1425.6ms
# Speed: 5.0ms preprocess, 1425.6ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
# 1/1 [==============================] - 0s 48ms/step
#
# 0: 384x640 4 persons, 1 sports ball, 1392.4ms
# Speed: 6.0ms preprocess, 1392.4ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
# 1/1 [==============================] - 0s 35ms/step
#
# 0: 384x640 4 persons, 1 sports ball, 1343.9ms
# Speed: 4.0ms preprocess, 1343.9ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# 1/1 [==============================] - 0s 47ms/step
#
# 0: 384x640 4 persons, 1 sports ball, 1352.6ms
# Speed: 5.0ms preprocess, 1352.6ms inference, 6.0ms postprocess per image at shape (1, 3, 384, 640)
# 1/1 [==============================] - 0s 39ms/step
#
# 0: 384x640 4 persons, 1 sports ball, 1483.8ms
# Speed: 4.0ms preprocess, 1483.8ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# 1/1 [==============================] - 0s 39ms/step
#
# 0: 384x640 4 persons, 1 sports ball, 1 clock, 1398.5ms
# Speed: 4.0ms preprocess, 1398.5ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
# 1/1 [==============================] - 0s 39ms/step
#
# 0: 384x640 4 persons, 1 sports ball, 1 tennis racket, 1384.1ms
# Speed: 5.0ms preprocess, 1384.1ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
# 1/1 [==============================] - 0s 35ms/step
#
# 0: 384x640 4 persons, 1 sports ball, 1 tennis racket, 1 clock, 1365.3ms
# Speed: 3.0ms preprocess, 1365.3ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# 1/1 [==============================] - 0s 35ms/step
#
# 0: 384x640 4 persons, 1 sports ball, 1 tennis racket, 1 clock, 1665.1ms
# Speed: 5.0ms preprocess, 1665.1ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
# 1/1 [==============================] - 0s 42ms/step
#
# 0: 384x640 4 persons, 1 sports ball, 1 clock, 1338.8ms
# Speed: 5.0ms preprocess, 1338.8ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
# 1/1 [==============================] - 0s 35ms/step
#
# 0: 384x640 4 persons, 1 sports ball, 1374.7ms
# Speed: 3.0ms preprocess, 1374.7ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
# 1/1 [==============================] - 0s 36ms/step
#
# 0: 384x640 4 persons, 1 sports ball, 1389.3ms
# Speed: 4.1ms preprocess, 1389.3ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
# 1/1 [==============================] - 0s 40ms/step
#
# 0: 384x640 4 persons, 1 sports ball, 1354.1ms
# Speed: 4.0ms preprocess, 1354.1ms inference, 5.0ms postprocess per image at shape (1, 3, 384, 640)
# 1/1 [==============================] - 0s 36ms/step
#
# 0: 384x640 4 persons, 1 sports ball, 1 baseball glove, 1391.5ms
# Speed: 4.0ms preprocess, 1391.5ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
# 1/1 [==============================] - 0s 37ms/step
#
# 0: 384x640 4 persons, 1 sports ball, 1567.5ms
# Speed: 5.0ms preprocess, 1567.5ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# 1/1 [==============================] - 0s 38ms/step
#
# 0: 384x640 4 persons, 1 sports ball, 1 clock, 1419.0ms
# Speed: 6.1ms preprocess, 1419.0ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
# 1/1 [==============================] - 0s 32ms/step
#
# 0: 384x640 4 persons, 1 sports ball, 1 clock, 1250.1ms
# Speed: 3.0ms preprocess, 1250.1ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# 1/1 [==============================] - 0s 38ms/step
#
# 0: 384x640 4 persons, 1 sports ball, 1429.9ms
# Speed: 5.0ms preprocess, 1429.9ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# 1/1 [==============================] - 0s 37ms/step
#
# 0: 384x640 4 persons, 1 sports ball, 1341.1ms
# Speed: 6.0ms preprocess, 1341.1ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
# 1/1 [==============================] - 0s 38ms/step
#
# 0: 384x640 4 persons, 1 sports ball, 1360.1ms
# Speed: 13.0ms preprocess, 1360.1ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
# 1/1 [==============================] - 0s 39ms/step
#
# 0: 384x640 4 persons, 1 sports ball, 1378.3ms
# Speed: 4.0ms preprocess, 1378.3ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# 1/1 [==============================] - 0s 43ms/step
#
# 0: 384x640 4 persons, 1 sports ball, 1414.6ms
# Speed: 5.7ms preprocess, 1414.6ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
# 1/1 [==============================] - 0s 34ms/step
#
# 0: 384x640 4 persons, 1 sports ball, 1433.2ms
# Speed: 5.0ms preprocess, 1433.2ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
# 1/1 [==============================] - 0s 45ms/step
#
# 0: 384x640 4 persons, 1 sports ball, 1608.1ms
# Speed: 6.0ms preprocess, 1608.1ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
# 1/1 [==============================] - 0s 40ms/step
#
# 0: 384x640 4 persons, 1 sports ball, 1409.0ms
# Speed: 5.0ms preprocess, 1409.0ms inference, 6.0ms postprocess per image at shape (1, 3, 384, 640)
# 1/1 [==============================] - 0s 36ms/step
#
# 0: 384x640 4 persons, 1 sports ball, 1642.5ms
# Speed: 3.0ms preprocess, 1642.5ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
# 1/1 [==============================] - 0s 40ms/step
#
# 0: 384x640 4 persons, 1 sports ball, 1451.5ms
# Speed: 4.0ms preprocess, 1451.5ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
# 1/1 [==============================] - 0s 34ms/step
#
# 0: 384x640 4 persons, 1 sports ball, 1388.6ms
# Speed: 4.0ms preprocess, 1388.6ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
# 1/1 [==============================] - 0s 34ms/step
#
# 0: 384x640 4 persons, 1 sports ball, 1485.2ms
# Speed: 5.0ms preprocess, 1485.2ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
# 1/1 [==============================] - 0s 35ms/step
#
# 0: 384x640 4 persons, 1 sports ball, 1285.2ms
# Speed: 3.0ms preprocess, 1285.2ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# 1/1 [==============================] - 0s 40ms/step
#
# 0: 384x640 4 persons, 1 sports ball, 1 baseball glove, 1403.3ms
# Speed: 4.7ms preprocess, 1403.3ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# 1/1 [==============================] - 0s 40ms/step
#
# 0: 384x640 4 persons, 1 sports ball, 1 baseball glove, 1431.8ms
# Speed: 4.0ms preprocess, 1431.8ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# 1/1 [==============================] - 0s 35ms/step
#
# 0: 384x640 4 persons, 1 sports ball, 1 baseball glove, 1413.9ms
# Speed: 4.0ms preprocess, 1413.9ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# 1/1 [==============================] - 0s 42ms/step
#
# 0: 384x640 4 persons, 1 sports ball, 1 baseball glove, 1402.0ms
# Speed: 5.0ms preprocess, 1402.0ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
# 1/1 [==============================] - 0s 35ms/step
#
# 0: 384x640 4 persons, 1 sports ball, 1 baseball glove, 1401.6ms
# Speed: 4.0ms preprocess, 1401.6ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# 1/1 [==============================] - 0s 46ms/step
#
# 0: 384x640 4 persons, 1 sports ball, 1 baseball glove, 1444.0ms
# Speed: 6.0ms preprocess, 1444.0ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
# 1/1 [==============================] - 0s 40ms/step
#
# 0: 384x640 4 persons, 1 sports ball, 1 baseball glove, 1 clock, 1449.1ms
# Speed: 4.0ms preprocess, 1449.1ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# 1/1 [==============================] - 0s 36ms/step
#
# 0: 384x640 4 persons, 1 sports ball, 1 baseball glove, 1398.9ms
# Speed: 3.0ms preprocess, 1398.9ms inference, 5.0ms postprocess per image at shape (1, 3, 384, 640)
# 1/1 [==============================] - 0s 40ms/step
#
# 0: 384x640 4 persons, 1 sports ball, 1 baseball glove, 1341.2ms
# Speed: 4.0ms preprocess, 1341.2ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# 1/1 [==============================] - 0s 38ms/step
#
# 0: 384x640 4 persons, 1 sports ball, 1 baseball glove, 1380.1ms
# Speed: 7.0ms preprocess, 1380.1ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
# 1/1 [==============================] - 0s 57ms/step
#
# 0: 384x640 4 persons, 1 sports ball, 1 baseball glove, 1517.5ms
# Speed: 7.0ms preprocess, 1517.5ms inference, 5.0ms postprocess per image at shape (1, 3, 384, 640)
# 1/1 [==============================] - 0s 41ms/step
#
# 0: 384x640 4 persons, 1 sports ball, 1 baseball glove, 1 tennis racket, 1370.1ms
# Speed: 3.0ms preprocess, 1370.1ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# 1/1 [==============================] - 0s 38ms/step
#
# 0: 384x640 4 persons, 1 sports ball, 1 tennis racket, 1335.8ms
# Speed: 3.0ms preprocess, 1335.8ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
# 1/1 [==============================] - 0s 41ms/step
#
# 0: 384x640 4 persons, 1 sports ball, 1 tennis racket, 1358.0ms
# Speed: 2.9ms preprocess, 1358.0ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
# 1/1 [==============================] - 0s 37ms/step
#
# 0: 384x640 4 persons, 1 sports ball, 1 tennis racket, 1350.5ms
# Speed: 4.0ms preprocess, 1350.5ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
# 1/1 [==============================] - 0s 42ms/step
#
# 0: 384x640 4 persons, 1 sports ball, 1 tennis racket, 1210.7ms
# Speed: 4.6ms preprocess, 1210.7ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# 1/1 [==============================] - 0s 33ms/step
#
# 0: 384x640 4 persons, 1 sports ball, 1 baseball glove, 1 clock, 1327.0ms
# Speed: 5.0ms preprocess, 1327.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# 1/1 [==============================] - 0s 51ms/step
#
# 0: 384x640 4 persons, 1 sports ball, 1 baseball glove, 1 clock, 1349.7ms
# Speed: 6.0ms preprocess, 1349.7ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# 1/1 [==============================] - 0s 36ms/step
#
# 0: 384x640 4 persons, 1 sports ball, 1 baseball glove, 1332.8ms
# Speed: 3.0ms preprocess, 1332.8ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# 1/1 [==============================] - 0s 35ms/step
#
# 0: 384x640 4 persons, 1 sports ball, 1 baseball glove, 1397.8ms
# Speed: 4.0ms preprocess, 1397.8ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
# 1/1 [==============================] - 0s 37ms/step
#
# 0: 384x640 4 persons, 1 sports ball, 1 baseball glove, 1346.8ms
# Speed: 5.0ms preprocess, 1346.8ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
# 1/1 [==============================] - 0s 47ms/step
#
# 0: 384x640 4 persons, 1 sports ball, 1 baseball glove, 1487.2ms
# Speed: 3.0ms preprocess, 1487.2ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# 1/1 [==============================] - 0s 39ms/step
#
# 0: 384x640 4 persons, 1 sports ball, 1 baseball glove, 1418.8ms
# Speed: 8.0ms preprocess, 1418.8ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# 1/1 [==============================] - 0s 39ms/step
#
# 0: 384x640 4 persons, 1 sports ball, 1 baseball glove, 1413.8ms
# Speed: 4.0ms preprocess, 1413.8ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# 1/1 [==============================] - 0s 34ms/step
#
# 0: 384x640 4 persons, 1 sports ball, 1 baseball glove, 1358.6ms
# Speed: 4.0ms preprocess, 1358.6ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# 1/1 [==============================] - 0s 33ms/step
#
# 0: 384x640 4 persons, 1 sports ball, 1403.7ms
# Speed: 5.0ms preprocess, 1403.7ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
# 1/1 [==============================] - 0s 35ms/step
#
# 0: 384x640 4 persons, 1 sports ball, 1 clock, 1393.3ms
# Speed: 5.0ms preprocess, 1393.3ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# 1/1 [==============================] - 0s 47ms/step
#
# 0: 384x640 4 persons, 2 sports balls, 1582.7ms
# Speed: 4.0ms preprocess, 1582.7ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# 1/1 [==============================] - 0s 42ms/step
#
# 0: 384x640 4 persons, 1 sports ball, 1430.0ms
# Speed: 5.0ms preprocess, 1430.0ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
# 1/1 [==============================] - 0s 34ms/step
#
# 0: 384x640 4 persons, 1 sports ball, 1421.3ms
# Speed: 4.0ms preprocess, 1421.3ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
# 1/1 [==============================] - 0s 33ms/step
#
# 0: 384x640 4 persons, 1 sports ball, 1349.1ms
# Speed: 3.0ms preprocess, 1349.1ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# 1/1 [==============================] - 0s 36ms/step
#
# 0: 384x640 4 persons, 1 sports ball, 1377.1ms
# Speed: 5.0ms preprocess, 1377.1ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
# 1/1 [==============================] - 0s 40ms/step
#
# 0: 384x640 4 persons, 1 sports ball, 1357.5ms
# Speed: 3.0ms preprocess, 1357.5ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# 1/1 [==============================] - 0s 64ms/step
#
# 0: 384x640 4 persons, 1 sports ball, 1271.9ms
# Speed: 6.0ms preprocess, 1271.9ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# 1/1 [==============================] - 0s 36ms/step
#
# 0: 384x640 4 persons, 1 sports ball, 1419.7ms
# Speed: 5.0ms preprocess, 1419.7ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
# 1/1 [==============================] - 0s 35ms/step
#
# 0: 384x640 4 persons, 1 sports ball, 1 baseball glove, 1392.3ms
# Speed: 4.0ms preprocess, 1392.3ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# 1/1 [==============================] - 0s 33ms/step
#
# 0: 384x640 4 persons, 1 sports ball, 1 clock, 1459.8ms
# Speed: 4.0ms preprocess, 1459.8ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# 1/1 [==============================] - 0s 51ms/step
#
# 0: 384x640 4 persons, 1395.8ms
# Speed: 4.0ms preprocess, 1395.8ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# 1/1 [==============================] - 0s 38ms/step
#
# 0: 384x640 4 persons, 1 clock, 1347.0ms
# Speed: 4.0ms preprocess, 1347.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# 1/1 [==============================] - 0s 40ms/step
#
# 0: 384x640 4 persons, 1355.1ms
# Speed: 5.0ms preprocess, 1355.1ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# 1/1 [==============================] - 0s 51ms/step
#
# 0: 384x640 4 persons, 1 sports ball, 1464.8ms
# Speed: 4.0ms preprocess, 1464.8ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# 1/1 [==============================] - 0s 32ms/step
#
# 0: 384x640 4 persons, 1 sports ball, 1771.9ms
# Speed: 4.0ms preprocess, 1771.9ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# 1/1 [==============================] - 0s 160ms/step
#
# 0: 384x640 4 persons, 1 sports ball, 1459.1ms
# Speed: 5.0ms preprocess, 1459.1ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# 1/1 [==============================] - 0s 35ms/step
#
# 0: 384x640 4 persons, 1 sports ball, 1 clock, 1478.1ms
# Speed: 4.0ms preprocess, 1478.1ms inference, 21.0ms postprocess per image at shape (1, 3, 384, 640)
# 1/1 [==============================] - 0s 58ms/step
#
# 0: 384x640 4 persons, 1 sports ball, 1631.1ms
# Speed: 4.0ms preprocess, 1631.1ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# 1/1 [==============================] - 0s 37ms/step
#
# 0: 384x640 4 persons, 1 sports ball, 1 clock, 1312.1ms
# Speed: 5.0ms preprocess, 1312.1ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
# 1/1 [==============================] - 0s 36ms/step
#
# 0: 384x640 4 persons, 1 sports ball, 1 clock, 1433.0ms
# Speed: 5.0ms preprocess, 1433.0ms inference, 5.0ms postprocess per image at shape (1, 3, 384, 640)
# 1/1 [==============================] - 0s 37ms/step
#
# 0: 384x640 4 persons, 1 sports ball, 1 clock, 1393.6ms
# Speed: 5.0ms preprocess, 1393.6ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# 1/1 [==============================] - 0s 34ms/step
#
# 0: 384x640 4 persons, 1 sports ball, 1 clock, 1389.3ms
# Speed: 4.0ms preprocess, 1389.3ms inference, 6.0ms postprocess per image at shape (1, 3, 384, 640)
# 1/1 [==============================] - 0s 38ms/step
#
# 0: 384x640 4 persons, 1 sports ball, 1356.0ms
# Speed: 5.0ms preprocess, 1356.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# 1/1 [==============================] - 0s 37ms/step
#
# 0: 384x640 4 persons, 1 sports ball, 1 clock, 1322.9ms
# Speed: 5.0ms preprocess, 1322.9ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# 1/1 [==============================] - 0s 34ms/step
#
# 0: 384x640 4 persons, 1 sports ball, 1413.7ms
# Speed: 5.0ms preprocess, 1413.7ms inference, 4.1ms postprocess per image at shape (1, 3, 384, 640)
# 1/1 [==============================] - 0s 35ms/step
#
# 0: 384x640 4 persons, 1 sports ball, 1360.4ms
# Speed: 4.0ms preprocess, 1360.4ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# 1/1 [==============================] - 0s 38ms/step
#
# 0: 384x640 4 persons, 1 sports ball, 1615.1ms
# Speed: 4.0ms preprocess, 1615.1ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
# 1/1 [==============================] - 0s 39ms/step
#
# 0: 384x640 4 persons, 1 sports ball, 1402.9ms
# Speed: 3.0ms preprocess, 1402.9ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# 1/1 [==============================] - 0s 34ms/step
#
# 0: 384x640 4 persons, 1 sports ball, 1 baseball glove, 1 clock, 1327.2ms
# Speed: 4.0ms preprocess, 1327.2ms inference, 3.8ms postprocess per image at shape (1, 3, 384, 640)
# 1/1 [==============================] - 0s 31ms/step
#
# 0: 384x640 4 persons, 1 sports ball, 1 baseball glove, 1276.8ms
# Speed: 7.0ms preprocess, 1276.8ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# 1/1 [==============================] - 0s 37ms/step
#
# 0: 384x640 4 persons, 1 sports ball, 1 baseball glove, 1 clock, 1446.4ms
# Speed: 5.0ms preprocess, 1446.4ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
# 1/1 [==============================] - 0s 38ms/step
#
# 0: 384x640 4 persons, 1 sports ball, 1 clock, 1318.4ms
# Speed: 4.0ms preprocess, 1318.4ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# 1/1 [==============================] - 0s 51ms/step
#
# 0: 384x640 4 persons, 1 sports ball, 1337.0ms
# Speed: 5.0ms preprocess, 1337.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# 1/1 [==============================] - 0s 42ms/step
#
# 0: 384x640 4 persons, 1 sports ball, 1332.0ms
# Speed: 4.0ms preprocess, 1332.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# 1/1 [==============================] - 0s 35ms/step
#
# 0: 384x640 4 persons, 1 sports ball, 1 tennis racket, 1324.8ms
# Speed: 4.0ms preprocess, 1324.8ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# 1/1 [==============================] - 0s 43ms/step
#
# 0: 384x640 4 persons, 1 sports ball, 1 tennis racket, 1356.2ms
# Speed: 4.0ms preprocess, 1356.2ms inference, 5.0ms postprocess per image at shape (1, 3, 384, 640)
# 1/1 [==============================] - 0s 42ms/step
#
# 0: 384x640 4 persons, 1 sports ball, 1 tennis racket, 1312.2ms
# Speed: 4.0ms preprocess, 1312.2ms inference, 5.0ms postprocess per image at shape (1, 3, 384, 640)
# 1/1 [==============================] - 0s 35ms/step
#
# 0: 384x640 4 persons, 2 sports balls, 1422.8ms
# Speed: 4.0ms preprocess, 1422.8ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
# 1/1 [==============================] - 0s 38ms/step
#
# 0: 384x640 4 persons, 2 sports balls, 1 clock, 1441.2ms
# Speed: 4.0ms preprocess, 1441.2ms inference, 5.0ms postprocess per image at shape (1, 3, 384, 640)
# 1/1 [==============================] - 0s 44ms/step
#
# 0: 384x640 4 persons, 2 sports balls, 1377.6ms
# Speed: 6.0ms preprocess, 1377.6ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
# 1/1 [==============================] - 0s 38ms/step
#
# 0: 384x640 4 persons, 2 sports balls, 1 clock, 1394.9ms
# Speed: 5.6ms preprocess, 1394.9ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# 1/1 [==============================] - 0s 39ms/step
#
# 0: 384x640 4 persons, 2 sports balls, 1 clock, 1592.5ms
# Speed: 5.0ms preprocess, 1592.5ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
# 1/1 [==============================] - 0s 39ms/step
#
# 0: 384x640 4 persons, 2 sports balls, 1 clock, 1438.1ms
# Speed: 3.0ms preprocess, 1438.1ms inference, 5.0ms postprocess per image at shape (1, 3, 384, 640)
# 1/1 [==============================] - 0s 69ms/step
#
# 0: 384x640 4 persons, 2 sports balls, 1399.1ms
# Speed: 4.0ms preprocess, 1399.1ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# 1/1 [==============================] - 0s 43ms/step
#
# 0: 384x640 4 persons, 2 sports balls, 1379.0ms
# Speed: 3.0ms preprocess, 1379.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# 1/1 [==============================] - 0s 35ms/step
#
# 0: 384x640 4 persons, 2 sports balls, 1340.0ms
# Speed: 6.0ms preprocess, 1340.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# 1/1 [==============================] - 0s 56ms/step
#
# 0: 384x640 4 persons, 2 sports balls, 1 clock, 1350.3ms
# Speed: 4.0ms preprocess, 1350.3ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
# 1/1 [==============================] - 0s 38ms/step
#
# 0: 384x640 4 persons, 2 sports balls, 1 clock, 1377.2ms
# Speed: 6.0ms preprocess, 1377.2ms inference, 2.8ms postprocess per image at shape (1, 3, 384, 640)
# 1/1 [==============================] - 0s 51ms/step
#
# 0: 384x640 4 persons, 2 sports balls, 1 clock, 1447.7ms
# Speed: 3.0ms preprocess, 1447.7ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# 1/1 [==============================] - 0s 39ms/step
#
# 0: 384x640 4 persons, 2 sports balls, 1372.9ms
# Speed: 6.0ms preprocess, 1372.9ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# 1/1 [==============================] - 0s 51ms/step
#
# 0: 384x640 4 persons, 2 sports balls, 1419.6ms
# Speed: 5.0ms preprocess, 1419.6ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# 1/1 [==============================] - 0s 38ms/step
#
# 0: 384x640 4 persons, 2 sports balls, 1373.9ms
# Speed: 5.0ms preprocess, 1373.9ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# 1/1 [==============================] - 0s 41ms/step
#
# 0: 384x640 4 persons, 2 sports balls, 1368.9ms
# Speed: 3.0ms preprocess, 1368.9ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# 1/1 [==============================] - 0s 40ms/step
#
# 0: 384x640 4 persons, 2 sports balls, 1502.5ms
# Speed: 4.0ms preprocess, 1502.5ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
# 1/1 [==============================] - 0s 35ms/step
#
# 0: 384x640 4 persons, 2 sports balls, 1443.3ms
# Speed: 8.1ms preprocess, 1443.3ms inference, 5.0ms postprocess per image at shape (1, 3, 384, 640)
# 1/1 [==============================] - 0s 46ms/step
#
# 0: 384x640 4 persons, 2 sports balls, 1378.1ms
# Speed: 4.0ms preprocess, 1378.1ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
# 1/1 [==============================] - 0s 35ms/step
#
# 0: 384x640 4 persons, 2 sports balls, 1 clock, 1562.1ms
# Speed: 3.3ms preprocess, 1562.1ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# 1/1 [==============================] - 0s 40ms/step
#
# 0: 384x640 4 persons, 1 sports ball, 1776.6ms
# Speed: 4.0ms preprocess, 1776.6ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
# 1/1 [==============================] - 0s 86ms/step
#
# 0: 384x640 4 persons, 2 sports balls, 1696.5ms
# Speed: 6.0ms preprocess, 1696.5ms inference, 5.0ms postprocess per image at shape (1, 3, 384, 640)
# 1/1 [==============================] - 0s 62ms/step
#
# 0: 384x640 4 persons, 2 sports balls, 1 clock, 2207.6ms
# Speed: 4.0ms preprocess, 2207.6ms inference, 5.0ms postprocess per image at shape (1, 3, 384, 640)
# 1/1 [==============================] - 0s 42ms/step
#
# 0: 384x640 4 persons, 1 sports ball, 2626.3ms
# Speed: 4.0ms preprocess, 2626.3ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
# 1/1 [==============================] - 0s 55ms/step
#
# 0: 384x640 4 persons, 1 sports ball, 1692.0ms
# Speed: 64.9ms preprocess, 1692.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# 1/1 [==============================] - 0s 36ms/step
#
# 0: 384x640 4 persons, 1 sports ball, 2024.9ms
# Speed: 9.0ms preprocess, 2024.9ms inference, 6.0ms postprocess per image at shape (1, 3, 384, 640)
# 1/1 [==============================] - 0s 48ms/step
#
# 0: 384x640 4 persons, 1 sports ball, 1527.5ms
# Speed: 4.0ms preprocess, 1527.5ms inference, 5.0ms postprocess per image at shape (1, 3, 384, 640)
# 1/1 [==============================] - 0s 49ms/step
#
# 0: 384x640 4 persons, 1 sports ball, 1571.0ms
# Speed: 6.0ms preprocess, 1571.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# 1/1 [==============================] - 0s 45ms/step
#
# 0: 384x640 4 persons, 1 sports ball, 1497.0ms
# Speed: 4.0ms preprocess, 1497.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# 1/1 [==============================] - 0s 34ms/step
#
# 0: 384x640 4 persons, 1 sports ball, 1458.4ms
# Speed: 4.0ms preprocess, 1458.4ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
# 1/1 [==============================] - 0s 38ms/step
#
# 0: 384x640 4 persons, 1 sports ball, 1474.5ms
# Speed: 4.0ms preprocess, 1474.5ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
# 1/1 [==============================] - 0s 53ms/step
#
# 0: 384x640 4 persons, 1 sports ball, 1502.7ms
# Speed: 5.0ms preprocess, 1502.7ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# 1/1 [==============================] - 0s 39ms/step
#
# 0: 384x640 4 persons, 1 sports ball, 1497.9ms
# Speed: 4.0ms preprocess, 1497.9ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
# 1/1 [==============================] - 0s 33ms/step
#
# 0: 384x640 4 persons, 1 sports ball, 1439.9ms
# Speed: 4.0ms preprocess, 1439.9ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# 1/1 [==============================] - 0s 34ms/step
#
# 0: 384x640 4 persons, 1 sports ball, 1564.0ms
# Speed: 3.6ms preprocess, 1564.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# 1/1 [==============================] - 0s 35ms/step
#
# 0: 384x640 4 persons, 1 sports ball, 1397.0ms
# Speed: 26.0ms preprocess, 1397.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# 1/1 [==============================] - 0s 35ms/step
#
# 0: 384x640 4 persons, 1 sports ball, 1325.9ms
# Speed: 5.0ms preprocess, 1325.9ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# 1/1 [==============================] - 0s 33ms/step
#
# 0: 384x640 4 persons, 1 sports ball, 1 clock, 1346.7ms
# Speed: 3.0ms preprocess, 1346.7ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# 1/1 [==============================] - 0s 37ms/step
#
# 0: 384x640 4 persons, 1 sports ball, 1373.1ms
# Speed: 5.0ms preprocess, 1373.1ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# 1/1 [==============================] - 0s 36ms/step
#
# 0: 384x640 4 persons, 1 sports ball, 1 clock, 1341.6ms
# Speed: 4.0ms preprocess, 1341.6ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
# 1/1 [==============================] - 0s 35ms/step
#
# 0: 384x640 4 persons, 1 sports ball, 1358.8ms
# Speed: 4.0ms preprocess, 1358.8ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# 1/1 [==============================] - 0s 43ms/step
#
# 0: 384x640 4 persons, 1 sports ball, 1 clock, 1326.6ms
# Speed: 5.0ms preprocess, 1326.6ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# 1/1 [==============================] - 0s 50ms/step
#
# 0: 384x640 4 persons, 1 sports ball, 1 clock, 1326.3ms
# Speed: 4.0ms preprocess, 1326.3ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
# 1/1 [==============================] - 0s 40ms/step
#
# 0: 384x640 4 persons, 1 sports ball, 1292.1ms
# Speed: 4.0ms preprocess, 1292.1ms inference, 3.1ms postprocess per image at shape (1, 3, 384, 640)
# 1/1 [==============================] - 0s 41ms/step
#
# 0: 384x640 4 persons, 1 sports ball, 1 clock, 1462.0ms
# Speed: 4.0ms preprocess, 1462.0ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
# 1/1 [==============================] - 0s 263ms/step
#
# 0: 384x640 4 persons, 1 sports ball, 1 clock, 1405.7ms
# Speed: 6.0ms preprocess, 1405.7ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# 1/1 [==============================] - 0s 84ms/step
#
# 0: 384x640 4 persons, 1 sports ball, 1 clock, 1640.4ms
# Speed: 3.0ms preprocess, 1640.4ms inference, 5.0ms postprocess per image at shape (1, 3, 384, 640)
# 1/1 [==============================] - 0s 37ms/step
#
# 0: 384x640 4 persons, 1 sports ball, 1 clock, 2079.9ms
# Speed: 4.0ms preprocess, 2079.9ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
# 1/1 [==============================] - 0s 60ms/step
#
# 0: 384x640 4 persons, 1 sports ball, 1 clock, 2104.7ms
# Speed: 11.0ms preprocess, 2104.7ms inference, 7.0ms postprocess per image at shape (1, 3, 384, 640)
# 1/1 [==============================] - 0s 45ms/step
#
# 0: 384x640 4 persons, 1 sports ball, 1 clock, 1854.9ms
# Speed: 6.0ms preprocess, 1854.9ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# 1/1 [==============================] - 0s 37ms/step
#
# 0: 384x640 4 persons, 1 sports ball, 1 clock, 1496.4ms
# Speed: 5.0ms preprocess, 1496.4ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# 1/1 [==============================] - 0s 39ms/step
#
# 0: 384x640 4 persons, 1 sports ball, 1577.5ms
# Speed: 4.0ms preprocess, 1577.5ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# 1/1 [==============================] - 0s 35ms/step
#
# 0: 384x640 4 persons, 1 sports ball, 2156.9ms
# Speed: 3.0ms preprocess, 2156.9ms inference, 7.0ms postprocess per image at shape (1, 3, 384, 640)
# 1/1 [==============================] - 0s 45ms/step
#
# 0: 384x640 4 persons, 1 sports ball, 1402.7ms
# Speed: 5.0ms preprocess, 1402.7ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# 1/1 [==============================] - 0s 33ms/step
#
# 0: 384x640 4 persons, 1 sports ball, 1431.2ms
# Speed: 4.0ms preprocess, 1431.2ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# 1/1 [==============================] - 0s 35ms/step
#
# 0: 384x640 4 persons, 1 sports ball, 1406.5ms
# Speed: 3.0ms preprocess, 1406.5ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
# 1/1 [==============================] - 0s 47ms/step
#
# 0: 384x640 4 persons, 1 sports ball, 1493.5ms
# Speed: 4.0ms preprocess, 1493.5ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# 1/1 [==============================] - 0s 34ms/step
#
# 0: 384x640 4 persons, 1 sports ball, 1 clock, 1713.1ms
# Speed: 9.0ms preprocess, 1713.1ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# 1/1 [==============================] - 0s 37ms/step
#
# 0: 384x640 4 persons, 1 sports ball, 1513.6ms
# Speed: 4.0ms preprocess, 1513.6ms inference, 9.0ms postprocess per image at shape (1, 3, 384, 640)
# 1/1 [==============================] - 0s 34ms/step
#
# 0: 384x640 4 persons, 1 sports ball, 1287.3ms
# Speed: 4.0ms preprocess, 1287.3ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# 1/1 [==============================] - 0s 40ms/step
#
# 0: 384x640 4 persons, 1 sports ball, 1402.9ms
# Speed: 3.7ms preprocess, 1402.9ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# 1/1 [==============================] - 0s 38ms/step
#
# 0: 384x640 4 persons, 1 sports ball, 1304.5ms
# Speed: 3.0ms preprocess, 1304.5ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# 1/1 [==============================] - 0s 37ms/step
#
# 0: 384x640 4 persons, 1 sports ball, 1571.0ms
# Speed: 4.0ms preprocess, 1571.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# 1/1 [==============================] - 0s 52ms/step
#
# ...
# 1/1 [==============================] - 0s 49ms/step
#
# 0: 384x640 4 persons, 1 sports ball, 1 chair, 1 clock, 1538.3ms
# Speed: 7.0ms preprocess, 1538.3ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
# 1/1 [==============================] - 0s 47ms/step
#
# 0: 384x640 4 persons, 1 sports ball, 1 chair, 1 clock, 1561.8ms
# Speed: 6.0ms preprocess, 1561.8ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
# 1/1 [==============================] - 0s 53ms/step
#
# 0: 384x640 4 persons, 1 sports ball, 1 chair, 1 clock, 2446.7ms
# Speed: 5.0ms preprocess, 2446.7ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
# 1/1 [==============================] - 0s 108ms/step
#
# 0: 384x640 4 persons, 1 sports ball, 1 bowl, 1 clock, 2737.2ms
# Speed: 16.0ms preprocess, 2737.2ms inference, 7.0ms postprocess per image at shape (1, 3, 384, 640)
# 1/1 [==============================] - 0s 55ms/step
#
# 0: 384x640 4 persons, 1 sports ball, 1 clock, 1544.9ms
# Speed: 11.6ms preprocess, 1544.9ms inference, 5.9ms postprocess per image at shape (1, 3, 384, 640)
# 1/1 [==============================] - 0s 52ms/step
#
# 0: 384x640 4 persons, 1 sports ball, 1 clock, 1556.2ms
# Speed: 7.0ms preprocess, 1556.2ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
# 1/1 [==============================] - 0s 38ms/step
#
# 0: 384x640 4 persons, 1 sports ball, 1 clock, 2913.4ms
# Speed: 5.0ms preprocess, 2913.4ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
# 1/1 [==============================] - 0s 58ms/step
#
# 0: 384x640 4 persons, 1 sports ball, 1 clock, 2266.1ms
# Speed: 34.0ms preprocess, 2266.1ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# 1/1 [==============================] - 0s 39ms/step
#
# 0: 384x640 4 persons, 1 sports ball, 1 chair, 1 clock, 1506.2ms
# Speed: 11.0ms preprocess, 1506.2ms inference, 8.0ms postprocess per image at shape (1, 3, 384, 640)
# 1/1 [==============================] - 0s 118ms/step
#
# 0: 384x640 4 persons, 1 sports ball, 1 chair, 1 clock, 1676.3ms
# Speed: 13.0ms preprocess, 1676.3ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
# 1/1 [==============================] - 0s 44ms/step
#
# 0: 384x640 4 persons, 1 sports ball, 1 chair, 1 clock, 2511.4ms
# Speed: 16.0ms preprocess, 2511.4ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# 1/1 [==============================] - 0s 54ms/step
#
# 0: 384x640 4 persons, 1 sports ball, 1 clock, 2331.3ms
# Speed: 16.0ms preprocess, 2331.3ms inference, 6.0ms postprocess per image at shape (1, 3, 384, 640)
# 1/1 [==============================] - 0s 39ms/step
#
# 0: 384x640 4 persons, 1 sports ball, 1 clock, 1549.9ms
# Speed: 6.0ms preprocess, 1549.9ms inference, 5.0ms postprocess per image at shape (1, 3, 384, 640)
# 1/1 [==============================] - 0s 47ms/step
#
# 0: 384x640 4 persons, 1 sports ball, 1 chair, 1 clock, 1632.7ms
# Speed: 5.0ms preprocess, 1632.7ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# 1/1 [==============================] - 0s 60ms/step
#
# 0: 384x640 4 persons, 1 sports ball, 1 chair, 1 clock, 3126.7ms
# Speed: 15.0ms preprocess, 3126.7ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
# 1/1 [==============================] - 0s 80ms/step
#
# 0: 384x640 4 persons, 1 sports ball, 1 chair, 1 clock, 1938.6ms
# Speed: 18.0ms preprocess, 1938.6ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# 1/1 [==============================] - 0s 40ms/step
#
# 0: 384x640 4 persons, 1 sports ball, 1 chair, 1 clock, 1518.0ms
# Speed: 7.0ms preprocess, 1518.0ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
# 1/1 [==============================] - 0s 38ms/step
#
# 0: 384x640 4 persons, 1 sports ball, 1 clock, 1559.5ms
# Speed: 18.0ms preprocess, 1559.5ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# 1/1 [==============================] - 0s 38ms/step
#
# 0: 384x640 4 persons, 1 sports ball, 1 clock, 2396.7ms
# Speed: 33.0ms preprocess, 2396.7ms inference, 17.0ms postprocess per image at shape (1, 3, 384, 640)
# 1/1 [==============================] - 0s 81ms/step
#
# 0: 384x640 4 persons, 1 sports ball, 1 chair, 1 clock, 2281.5ms
# Speed: 13.0ms preprocess, 2281.5ms inference, 7.0ms postprocess per image at shape (1, 3, 384, 640)
# 1/1 [==============================] - 0s 38ms/step
#
# 0: 384x640 4 persons, 1 sports ball, 1 clock, 3226.2ms
# Speed: 24.0ms preprocess, 3226.2ms inference, 11.0ms postprocess per image at shape (1, 3, 384, 640)
# 1/1 [==============================] - 0s 83ms/step
#
# 0: 384x640 4 persons, 1 sports ball, 1 chair, 1 clock, 2107.8ms
# Speed: 18.0ms preprocess, 2107.8ms inference, 2.5ms postprocess per image at shape (1, 3, 384, 640)
# 1/1 [==============================] - 0s 48ms/step
#
# 0: 384x640 4 persons, 1 sports ball, 1 chair, 1 clock, 1582.7ms
# Speed: 19.0ms preprocess, 1582.7ms inference, 8.0ms postprocess per image at shape (1, 3, 384, 640)
# 1/1 [==============================] - 0s 42ms/step
#
# 0: 384x640 4 persons, 1 sports ball, 1 clock, 1564.4ms
# Speed: 28.0ms preprocess, 1564.4ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# 1/1 [==============================] - 0s 64ms/step
#
# 0: 384x640 4 persons, 1 sports ball, 1 chair, 1 clock, 2825.6ms
# Speed: 25.0ms preprocess, 2825.6ms inference, 9.0ms postprocess per image at shape (1, 3, 384, 640)
# 1/1 [==============================] - 0s 79ms/step
#
# 0: 384x640 4 persons, 1 sports ball, 1 chair, 1 clock, 1983.2ms
# Speed: 99.6ms preprocess, 1983.2ms inference, 7.0ms postprocess per image at shape (1, 3, 384, 640)
# 1/1 [==============================] - 0s 43ms/step
#
# 0: 384x640 4 persons, 1 sports ball, 1 chair, 1 clock, 1650.3ms
# Speed: 60.0ms preprocess, 1650.3ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# 1/1 [==============================] - 0s 51ms/step
#
# 0: 384x640 4 persons, 1 sports ball, 1 chair, 1 clock, 2117.0ms
# Speed: 7.0ms preprocess, 2117.0ms inference, 13.0ms postprocess per image at shape (1, 3, 384, 640)
# 1/1 [==============================] - 0s 122ms/step
#
# 0: 384x640 4 persons, 1 sports ball, 1 chair, 1 clock, 3183.0ms
# Speed: 35.0ms preprocess, 3183.0ms inference, 9.0ms postprocess per image at shape (1, 3, 384, 640)
# 1/1 [==============================] - 0s 64ms/step
#
# 0: 384x640 4 persons, 1 sports ball, 1 chair, 1 clock, 1635.0ms
# Speed: 11.0ms preprocess, 1635.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# 1/1 [==============================] - 0s 47ms/step
#
# 0: 384x640 4 persons, 1 sports ball, 1 clock, 1962.8ms
# Speed: 7.0ms preprocess, 1962.8ms inference, 3.3ms postprocess per image at shape (1, 3, 384, 640)
# 1/1 [==============================] - 0s 56ms/step
#
# 0: 384x640 4 persons, 2 sports balls, 1 clock, 2720.0ms
# Speed: 13.3ms preprocess, 2720.0ms inference, 13.0ms postprocess per image at shape (1, 3, 384, 640)
# 1/1 [==============================] - 0s 85ms/step
#
# 0: 384x640 4 persons, 2 sports balls, 1 clock, 2294.4ms
# Speed: 21.0ms preprocess, 2294.4ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
# 1/1 [==============================] - 0s 40ms/step
#
# 0: 384x640 4 persons, 1 sports ball, 1 clock, 1507.0ms
# Speed: 29.0ms preprocess, 1507.0ms inference, 7.0ms postprocess per image at shape (1, 3, 384, 640)
# 1/1 [==============================] - 0s 44ms/step
#
# 0: 384x640 5 persons, 1 sports ball, 1 clock, 1595.1ms
# Speed: 6.0ms preprocess, 1595.1ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
# 1/1 [==============================] - 0s 38ms/step
#
# 0: 384x640 4 persons, 2 sports balls, 1 clock, 2375.2ms
# Speed: 13.0ms preprocess, 2375.2ms inference, 10.0ms postprocess per image at shape (1, 3, 384, 640)
# 1/1 [==============================] - 0s 89ms/step
#
# 0: 384x640 4 persons, 2 sports balls, 1 chair, 1 clock, 2501.4ms
# Speed: 21.2ms preprocess, 2501.4ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# 1/1 [==============================] - 0s 49ms/step
#
# 0: 384x640 4 persons, 2 sports balls, 1 clock, 1610.6ms
# Speed: 11.0ms preprocess, 1610.6ms inference, 5.0ms postprocess per image at shape (1, 3, 384, 640)
# 1/1 [==============================] - 0s 48ms/step
#
# 0: 384x640 4 persons, 2 sports balls, 1 chair, 1 clock, 1613.1ms
# Speed: 6.0ms preprocess, 1613.1ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# 1/1 [==============================] - 0s 41ms/step
#
# 0: 384x640 4 persons, 2 sports balls, 1 clock, 2651.9ms
# Speed: 36.0ms preprocess, 2651.9ms inference, 13.0ms postprocess per image at shape (1, 3, 384, 640)
# 1/1 [==============================] - 0s 66ms/step
#
# 0: 384x640 4 persons, 2 sports balls, 1 clock, 2293.1ms
# Speed: 67.0ms preprocess, 2293.1ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# 1/1 [==============================] - 0s 52ms/step
#
# 0: 384x640 4 persons, 2 sports balls, 1636.7ms
# Speed: 10.0ms preprocess, 1636.7ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# 1/1 [==============================] - 0s 38ms/step
#
# 0: 384x640 4 persons, 2 sports balls, 1 clock, 1549.3ms
# Speed: 27.0ms preprocess, 1549.3ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# 1/1 [==============================] - 0s 87ms/step
#
# 0: 384x640 4 persons, 2 sports balls, 1 clock, 2882.4ms
# Speed: 14.0ms preprocess, 2882.4ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# 1/1 [==============================] - 0s 83ms/step
#
# 0: 384x640 4 persons, 2 sports balls, 1 clock, 1883.6ms
# Speed: 47.0ms preprocess, 1883.6ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# 1/1 [==============================] - 0s 41ms/step
#
# 0: 384x640 4 persons, 2 sports balls, 1 clock, 1513.3ms
# Speed: 11.0ms preprocess, 1513.3ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# 1/1 [==============================] - 0s 48ms/step
#
# 0: 384x640 4 persons, 1 sports ball, 1580.2ms
# Speed: 12.3ms preprocess, 1580.2ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# 1/1 [==============================] - 0s 58ms/step
#
# 0: 384x640 4 persons, 2 sports balls, 2724.5ms
# Speed: 40.0ms preprocess, 2724.5ms inference, 6.0ms postprocess per image at shape (1, 3, 384, 640)
# 1/1 [==============================] - 0s 83ms/step
#
# 0: 384x640 4 persons, 2 sports balls, 1 clock, 2034.7ms
# Speed: 12.0ms preprocess, 2034.7ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# 1/1 [==============================] - 0s 49ms/step
#
# 0: 384x640 4 persons, 2 sports balls, 1 clock, 1569.5ms
# Speed: 8.0ms preprocess, 1569.5ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# 1/1 [==============================] - 0s 50ms/step
#
# 0: 384x640 4 persons, 1 sports ball, 1 clock, 1623.8ms
# Speed: 6.0ms preprocess, 1623.8ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
# 1/1 [==============================] - 0s 64ms/step
#
# 0: 384x640 4 persons, 1 sports ball, 1 clock, 2719.3ms
# Speed: 35.0ms preprocess, 2719.3ms inference, 14.0ms postprocess per image at shape (1, 3, 384, 640)
# 1/1 [==============================] - 0s 67ms/step
#
# 0: 384x640 4 persons, 1 sports ball, 1 clock, 1967.6ms
# Speed: 48.0ms preprocess, 1967.6ms inference, 9.0ms postprocess per image at shape (1, 3, 384, 640)
# 1/1 [==============================] - 0s 53ms/step
#
# 0: 384x640 4 persons, 1 sports ball, 1 clock, 1544.5ms
# Speed: 33.0ms preprocess, 1544.5ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
# 1/1 [==============================] - 0s 47ms/step
#
# 0: 384x640 4 persons, 1 sports ball, 1 clock, 1807.3ms
# Speed: 11.0ms preprocess, 1807.3ms inference, 8.0ms postprocess per image at shape (1, 3, 384, 640)
# 1/1 [==============================] - 0s 85ms/step
#
# 0: 384x640 4 persons, 1 sports ball, 1 clock, 2524.6ms
# Speed: 17.0ms preprocess, 2524.6ms inference, 5.0ms postprocess per image at shape (1, 3, 384, 640)
# 1/1 [==============================] - 0s 70ms/step
#
# 0: 384x640 4 persons, 1 sports ball, 1 clock, 2045.3ms
# Speed: 22.1ms preprocess, 2045.3ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
# 1/1 [==============================] - 0s 41ms/step
#
# 0: 384x640 4 persons, 1 sports ball, 1 clock, 1499.6ms
# Speed: 5.0ms preprocess, 1499.6ms inference, 8.0ms postprocess per image at shape (1, 3, 384, 640)
# 1/1 [==============================] - 0s 43ms/step
#
# 0: 384x640 4 persons, 1 sports ball, 1 clock, 1669.2ms
# Speed: 11.0ms preprocess, 1669.2ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
# 1/1 [==============================] - 0s 67ms/step
#
# 0: 384x640 4 persons, 1 sports ball, 1 clock, 2399.8ms
# Speed: 18.0ms preprocess, 2399.8ms inference, 7.0ms postprocess per image at shape (1, 3, 384, 640)
# 1/1 [==============================] - 0s 71ms/step
#
# 0: 384x640 5 persons, 1 sports ball, 1 tennis racket, 1 clock, 1975.7ms
# Speed: 52.0ms preprocess, 1975.7ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# 1/1 [==============================] - 0s 53ms/step
#
# 0: 384x640 5 persons, 1 sports ball, 1 tennis racket, 1 clock, 1476.7ms
# Speed: 6.0ms preprocess, 1476.7ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# 1/1 [==============================] - 0s 41ms/step
#
# 0: 384x640 4 persons, 1 sports ball, 1 clock, 1488.2ms
# Speed: 18.0ms preprocess, 1488.2ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# 1/1 [==============================] - 0s 63ms/step
#
# 0: 384x640 5 persons, 1 sports ball, 1 tennis racket, 2551.8ms
# Speed: 23.0ms preprocess, 2551.8ms inference, 10.0ms postprocess per image at shape (1, 3, 384, 640)
# 1/1 [==============================] - 0s 94ms/step
#
# 0: 384x640 5 persons, 1 sports ball, 1 tennis racket, 2169.8ms
# Speed: 178.0ms preprocess, 2169.8ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# 1/1 [==============================] - 0s 45ms/step
# [[153, 121, 139, 122, 115, 122], [142, 157, 144, 119, 114, 122], [149, 146, 146, 122, 118, 121], [104, 100, 132, 125, 109, 128], [129, 142, 143, 126, 122, 123]]
# PDF created for 1
# PDF created for 2
# PDF created for 3
# PDF created for 4
# PDF created for 5
# ---------------------------------------------------------------------------
# PermissionError                           Traceback (most recent call last)
# Cell In[6], line 160
#     156     Path(pdf_init_path).mkdir(parents=True,exist_ok=True)
#     157     create_combined_pdf(pdf_init_path, os.path.join(pdf_init_path,f"{str(Path(path).stem)}_shot_report.pdf"),angles_for_pdf)
# --> 160 do_analysis(r'C:\Users\bkj\Documents\GitHub\projects\Upwork\videos\CharlieBrownDelaware5Shots.mov')
#
# Cell In[6], line 157, in do_analysis(path)
#     155 pdf_init_path = os.path.join('report',f"{str(Path(path).stem)}")
#     156 Path(pdf_init_path).mkdir(parents=True,exist_ok=True)
# --> 157 create_combined_pdf(pdf_init_path, os.path.join(pdf_init_path,f"{str(Path(path).stem)}_shot_report.pdf"),angles_for_pdf)
#
# Cell In[2], line 399, in create_combined_pdf(main_folder, pdf_filename, angles)
#     396             print(f'Subfolder {subfolder} does not contain 2 images.')
#     398 # Save the final PDF
# --> 399 merger.write(pdf_filename)
#     400 merger.close()
#     402 # Remove individual subfolder PDFs
#
# File c:\Users\bkj\AppData\Local\Programs\Python\Python310\lib\site-packages\PyPDF2\_merger.py:348, in PdfMerger.write(self, fileobj)
#     345 self._write_outline()
#     347 # Write the output to the file
# --> 348 my_file, ret_fileobj = self.output.write(fileobj)
#     350 if my_file:
#     351     ret_fileobj.close()
#
# File c:\Users\bkj\AppData\Local\Programs\Python\Python310\lib\site-packages\PyPDF2\_writer.py:986, in PdfWriter.write(self, stream)
#     983     raise ValueError(f"Output(stream={stream}) is empty.")
#     985 if isinstance(stream, (str, Path)):
# --> 986     stream = FileIO(stream, "wb")
#     987     self.with_as_usage = True  #
#     988     my_file = True
#
# PermissionError: [Errno 13] Permission denied: 'report\\CharlieBrownDelaware5Shots\\CharlieBrownDelaware5Shots_shot_report.pdf'

# %%
path = Path(r'C:\Users\bkj\Documents\GitHub\projects\Upwork\videos\CharlieBrownDelaware5Shots.mov')

# %%
path.exists()
# Out:
# True

# %%
def create_combined_pdf(main_folder, pdf_filename):
    merger = PdfMerger()
    # Iterate through subfolders
    for subfolder in os.listdir(main_folder):
        subfolder_path = os.path.join(main_folder, subfolder)

        # Check if the item in the main folder is a subfolder
        if os.path.isdir(subfolder_path):

            # List image files in the subfolder
            image_files = [file for file in os.listdir(subfolder_path) if file.lower().endswith(('.png', '.jpg', '.jpeg'))]

            # Check if there are exactly 2 image files
            i = 0
            if len(image_files) == 2:
                image_paths = [os.path.join(subfolder_path, file) for file in image_files]
                
                # sheet_filename = f'{subfolder}.pdf'
                sheet_filename = os.path.join(subfolder_path,f'{subfolder}.pdf')


                # Append the sheet to the main PDF
                merger.append(sheet_filename)
                i += 1
            else:
                print(f'Subfolder {subfolder} does not contain 2 images.')

    # Save the final PDF
    merger.write(pdf_filename)
    merger.close()

    # Remove individual subfolder PDFs
    for subfolder in os.listdir(main_folder):
        subfolder_path = os.path.join(main_folder, subfolder)
        if os.path.isdir(subfolder_path):
            pdf_path = os.path.join(main_folder,subfolder_path, f'{subfolder}.pdf')
            print(pdf_path)
            if os.path.exists(pdf_path):
                os.remove(pdf_path)

    print('PDF creation complete.')

# %%
pdf_init_path = os.path.join('report',f"{str(Path(path).stem)}")
Path(pdf_init_path).mkdir(parents=True,exist_ok=True)
create_combined_pdf(pdf_init_path, os.path.join(pdf_init_path,f"{str(Path(path).stem)}_shot_report.pdf"))
# Out:
# report\CharlieBrownDelaware5Shots\report\CharlieBrownDelaware5Shots\1\1.pdf
# report\CharlieBrownDelaware5Shots\report\CharlieBrownDelaware5Shots\2\2.pdf
# report\CharlieBrownDelaware5Shots\report\CharlieBrownDelaware5Shots\3\3.pdf
# report\CharlieBrownDelaware5Shots\report\CharlieBrownDelaware5Shots\4\4.pdf
# report\CharlieBrownDelaware5Shots\report\CharlieBrownDelaware5Shots\5\5.pdf
# PDF creation complete.
